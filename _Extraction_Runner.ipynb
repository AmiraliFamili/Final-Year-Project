# %%
# =============================================================================
# CELL 1 – IMPORTS, DARK THEME, AND HELPERS
# =============================================================================

import importlib
import sys
import json
from pathlib import Path
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from IPython.display import display, HTML, Markdown

# -------------------- Dark Theme --------------------
display(HTML("""
<style>
    body, .jp-Notebook, .jp-OutputArea-output, .jp-RenderedHTMLCommon {
        background-color: #1e1e1e !important;
        color: #d4d4d4 !important;
    }
    h2, h3, h4 {
        color: #4fc3f7 !important;
        border-bottom: 2px solid #3498db !important;
        padding-bottom: 4px;
    }
    b, strong { color: #f48fb1 !important; }
    .highlight {
        background-color: #2d2d2d !important;
        padding: 10px;
        border-left: 4px solid #3498db;
        margin: 4px 0;
        color: #d4d4d4;
    }
    code {
        background-color: #333 !important;
        color: #ffcc80 !important;
        padding: 2px 4px;
        border-radius: 4px;
    }
    .dataframe {
        background-color: #2d2d2d !important;
        color: #d4d4d4 !important;
    }
</style>
"""))

# -------------------- Verbosity Flags --------------------
SHOW_VERBOSE = True
SHOW_INFO = True
SHOW_CRITICAL = True
SHOW_DEBUG = True
# For demonstration, we keep them False to reduce output; you can set True as needed.


# -------------------- Import Extraction Module --------------------
import importlib, Extraction as EX
importlib.reload(EX)
DATASETS, CSV_HASHES = EX.discover_processed_datasets(show_info=True)
print(sorted(DATASETS), {k: len(v) for k, v in DATASETS.items()}) # expect amazon_polarity at 100000 rows, and the other 7 datasets at their canonical sizes.

# -------------------- Helper Functions --------------------
def display_title(title: str):
    display(HTML(f"<h2>{title}</h2>"))

def display_info(message: str):
    display(HTML(f"<div class='highlight'>{message}</div>"))
    

def discover_extractions(exp_root: Path) -> pd.DataFrame:
    rows = []
    for f in exp_root.rglob("extraction.json"):
        parts = f.relative_to(exp_root).parts
        try:
            models_idx = parts.index("models")
            datasets_idx = parts.index("datasets")
            model = "/".join(parts[models_idx+1:datasets_idx])
            dataset = parts[datasets_idx+1]
            rows.append({"model": model, "dataset": dataset, "path": str(f)})
        except ValueError:
            rows.append({"model": None, "dataset": None, "path": str(f)})
    return pd.DataFrame(rows)

def load_experiment_results(exp_root: Path) -> pd.DataFrame:
    """
    Load all extraction results from the experiment directory, inferring model and
    dataset names from the file path if they are missing in the JSON.
    """
    records = []
    exp_root = Path(exp_root)
    if not exp_root.exists():
        return pd.DataFrame()

    for meta_file in exp_root.rglob("extraction.json"):
        try:
            with open(meta_file, "r") as f:
                meta = json.load(f)

            # Extract model and dataset from path (most reliable)
            parts = meta_file.relative_to(exp_root).parts
            try:
                models_idx = parts.index("models")
                datasets_idx = parts.index("datasets")
                model = "/".join(parts[models_idx+1:datasets_idx])
                dataset = parts[datasets_idx+1]
            except ValueError:
                # Fallback to metadata
                model = meta.get("model", {}).get("name")
                dataset = meta.get("dataset", {}).get("name")

            record = {
                "experiment_id": meta.get("experiment_id"),
                "model": model,
                "dataset": dataset,
                "status": meta.get("status"),
                "completed_samples": meta.get("performance", {}).get("completed_samples"),
                "total_samples": meta.get("dataset", {}).get("samples"),
                "batch_size": meta.get("extraction", {}).get("batch_size"),
                "pooling": meta.get("extraction", {}).get("pooling"),
                "max_length": meta.get("extraction", {}).get("max_length"),
                "samples_per_second": meta.get("performance", {}).get("samples_per_second"),
                "tokens_per_second": meta.get("performance", {}).get("tokens_per_second"),
                "elapsed_seconds": meta.get("performance", {}).get("elapsed_seconds"),
                "error": None,
                "text_column": meta.get("dataset", {}).get("text_column"),
                "label_column": meta.get("dataset", {}).get("labels", {}).get("label_column"),
            }
            records.append(record)
        except Exception:
            continue

    return pd.DataFrame(records)

print("Environment ready. Dark theme applied.")
# Out:
# <style>
#     body, .jp-Notebook, .jp-OutputArea-output, .jp-RenderedHTMLCommon {
#         background-color: #1e1e1e !important;
#         color: #d4d4d4 !important;
#     }
#     h2, h3, h4 {
#         color: #4fc3f7 !important;
#         border-bottom: 2px solid #3498db !important;
#         padding-bottom: 4px;
#     }
#     b, strong { color: #f48fb1 !important; }
#     .highlight {
#         background-color: #2d2d2d !important;
#         padding: 10px;
#         border-left: 4px solid #3498db;
#         margin: 4px 0;
#         color: #d4d4d4;
#     }
#     code {
#         background-color: #333 !important;
#         color: #ffcc80 !important;
#         padding: 2px 4px;
#         border-radius: 4px;
#     }
#     .dataframe {
#         background-color: #2d2d2d !important;
#         color: #d4d4d4 !important;
#     }
# </style>
#   ✓ amazon_polarity            3,993,715 rows  sha256=869cdc40c857  (amazon_polarity/processed/amazon_polarity_clean.csv)
#   ✓ emotion                      19,999 rows  sha256=5306dde7d824  (emotion/processed/emotion_clean.csv)
#   ✓ goemo                        54,039 rows  sha256=567885691ac5  (goemo/processed/goemo_clean.csv)
#   ✓ isear                         7,532 rows  sha256=075d2d987106  (isear/processed/isear_clean.csv)
#   ✓ sst2                         69,676 rows  sha256=c86b94b4337b  (sst2/processed/sst2_clean.csv)
#   ✓ tweet_eval_emotion            5,027 rows  sha256=2791d0b2c71d  (tweet_eval_emotion/processed/tweet_eval_emotion_clean.csv)
#
#   · emotion_dataset_100k       skipped — no processed CSV
#   · empathetic                 skipped — no processed CSV
# ['amazon_polarity', 'emotion', 'goemo', 'isear', 'sst2', 'tweet_eval_emotion'] {'amazon_polarity': 3993715, 'emotion': 19999, 'goemo': 54039, 'isear': 7532, 'sst2': 69676, 'tweet_eval_emotion': 5027}
# Environment ready. Dark theme applied.

# %%
# =============================================================================
# CELL 2 — CANONICAL DATASET DISCOVERY (drop-in, no registry module)
# =============================================================================

from pathlib import Path
import importlib
import Extraction as EX
importlib.reload(EX)

display_title("Processed dataset discovery")

DATASETS, CSV_HASHES = EX.discover_processed_datasets(
    datasets_root=EX.PROCESSED_DATASETS_ROOT,
    show_info=True,
)

display_info(
    f"<b>{len(DATASETS)}</b> processed datasets discovered under "
    f"<code>{EX.PROCESSED_DATASETS_ROOT}</code>"
)

# Visual summary
summary = pd.DataFrame([
    {
        "name": name,
        "rows": len(df),
        "columns": ", ".join(df.columns),
        "csv_sha256": CSV_HASHES[name][:16] + "…",
        "sample_label": str(df["label"].iloc[0]),
    }
    for name, df in DATASETS.items()
])
display(summary)

# Contract checks
for name, df in DATASETS.items():
    assert list(df.columns) == list(EX.PROCESSED_COLUMNS), f"{name}: bad columns"
    assert df.index.is_unique and df.index[0] == 0 and df.index[-1] == len(df) - 1, \
        f"{name}: index must be a clean RangeIndex so row i ↔ hidden_states[i]"
    assert df["label"].map(lambda x: isinstance(x, list) and len(x) > 0).all(), \
        f"{name}: all labels must be non-empty Python lists"

display_info("✅ All datasets satisfy the extraction contract.")
# Out:
# <h2>Processed dataset discovery</h2>
#   ✓ amazon_polarity            3,993,715 rows  sha256=869cdc40c857  (amazon_polarity/processed/amazon_polarity_clean.csv)
#   ✓ emotion                      19,999 rows  sha256=5306dde7d824  (emotion/processed/emotion_clean.csv)
#   ✓ goemo                        54,039 rows  sha256=567885691ac5  (goemo/processed/goemo_clean.csv)
#   ✓ isear                         7,532 rows  sha256=075d2d987106  (isear/processed/isear_clean.csv)
#   ✓ sst2                         69,676 rows  sha256=c86b94b4337b  (sst2/processed/sst2_clean.csv)
#   ✓ tweet_eval_emotion            5,027 rows  sha256=2791d0b2c71d  (tweet_eval_emotion/processed/tweet_eval_emotion_clean.csv)
#
#   · emotion_dataset_100k       skipped — no processed CSV
#   · empathetic                 skipped — no processed CSV
# <div class='highlight'><b>6</b> processed datasets discovered under <code>/Volumes/Amirali/datasets</code></div>
#                  name     rows                             columns  \
# 0     amazon_polarity  3993715  clean_text, label, sentiment_score
# 1             emotion    19999  clean_text, label, sentiment_score
# 2               goemo    54039  clean_text, label, sentiment_score
# 3               isear     7532  clean_text, label, sentiment_score
# 4                sst2    69676  clean_text, label, sentiment_score
# 5  tweet_eval_emotion     5027  clean_text, label, sentiment_score
#
#           csv_sha256 sample_label
# 0  869cdc40c85740ca…          [1]
# 1  5306dde7d8241c52…          [0]
# 2  567885691ac5f48b…         [27]
# 3  075d2d9871063d19…          [1]
# 4  c86b94b4337b8b2a…          [0]
# 5  2791d0b2c71d6d26…          [2]
# <div class='highlight'>✅ All datasets satisfy the extraction contract.</div>

# %%
# =============================================================================
# CELL 2.5 — DETECT PENDING (MODEL, DATASET) PAIRS
# =============================================================================
import numpy as np
from pathlib import Path

def dataset_is_done(model_name: str, dataset_name: str) -> bool:
    """True iff this (model, dataset) folder has a fully-True completed.npy."""
    d = EX.build_dataset_directory(model_name, dataset_name)
    comp = d / "completed.npy"
    meta = d / "extraction.json"
    if not (comp.exists() and meta.exists()):
        return False
    try:
        c = np.load(comp, mmap_mode="r")
        return bool(c.all())
    except Exception:
        return False

def model_is_done(model_name: str) -> bool:
    return all(dataset_is_done(model_name, ds) for ds in DATASETS)

ALL_MODELS = list(EX.ALL_PRIMARY_MODEL_NAMES)
DONE_MODELS    = [m for m in ALL_MODELS if model_is_done(m)]
PENDING_MODELS = [m for m in ALL_MODELS if not model_is_done(m)]

print(f"Total registered : {len(ALL_MODELS)}")
print(f"Complete         : {len(DONE_MODELS)}")
print(f"Pending          : {len(PENDING_MODELS)}")
for m in PENDING_MODELS:
    done_ds = sum(dataset_is_done(m, ds) for ds in DATASETS)
    print(f"  · {m:<55}  {done_ds}/{len(DATASETS)} datasets done")
# Out:
# Total registered : 25
# Complete         : 0
# Pending          : 25
#   · google-bert/bert-base-uncased                            5/6 datasets done
#   · distilbert/distilbert-base-uncased                       0/6 datasets done
#   · FacebookAI/roberta-base                                  0/6 datasets done
#   · google/electra-small-discriminator                       0/6 datasets done
#   · microsoft/deberta-v3-small                               0/6 datasets done
#   · gpt2                                                     0/6 datasets done
#   · EleutherAI/gpt-neo-125m                                  0/6 datasets done
#   · facebook/opt-125m                                        0/6 datasets done
#   · HuggingFaceTB/SmolLM2-135M                               0/6 datasets done
#   · HuggingFaceTB/SmolLM2-360M                               0/6 datasets done
#   · google/gemma-3-270m                                      0/6 datasets done
#   · Qwen/Qwen2-0.5B                                          4/6 datasets done
#   · Qwen/Qwen2.5-0.5B                                        2/6 datasets done
#   · Qwen/Qwen3-0.6B-Base                                     4/6 datasets done
#   · Qwen/Qwen2-1.5B                                          0/6 datasets done
#   · Qwen/Qwen2.5-1.5B                                        0/6 datasets done
#   · Qwen/Qwen2.5-3B                                          0/6 datasets done
#   · Qwen/Qwen3-1.7B-Base                                     0/6 datasets done
#   · HuggingFaceTB/SmolLM2-1.7B                               0/6 datasets done
#   · TinyLlama/TinyLlama-1.1B-intermediate-step-1431k-3T      0/6 datasets done
#   · google/gemma-3-1b-pt                                     0/6 datasets done
#   · meta-llama/Llama-3.2-1B                                  0/6 datasets done
#   · Qwen/Qwen3-4B-Base                                       0/6 datasets done
#   · meta-llama/Llama-3.2-3B                                  0/6 datasets done
#   · google/gemma-3-4b-pt                                     0/6 datasets done

# %%
import importlib
importlib.reload(EX)          # picks up the patched _load_and_apply_order

GATED = {
    "google/gemma-3-270m",
    "google/gemma-3-1b-pt",
    "google/gemma-3-4b-pt",
    "meta-llama/Llama-3.2-1B",
    "meta-llama/Llama-3.2-3B",
}
TOO_BIG = {"Qwen/Qwen2.5-3B", "Qwen/Qwen3-1.7B-Base"}   # exceed 8 GiB at fp32

TARGET_MODELS = [m for m in PENDING_MODELS if m not in GATED | TOO_BIG]

print(f"Running {len(TARGET_MODELS)} models")

results = EX.run_experiments( # actual run
    datasets=DATASETS,
    dataset_csv_hashes=CSV_HASHES,
    model_names=TARGET_MODELS,
    pooling="mean",
    max_length=128,
    use_half_precision=True,
    flush_every_batches=8,
    continue_on_model_error=True,
    experiment_id="master_v2",
    show_verbose=True, show_info=True, show_critical=True, show_debug=False,
)


print(f"\nRecords : {len(results)}")
# Out:
# Running 18 models
#   ✓ HF cache configured: /Volumes/Amirali/.hf_cache/hub
#
# ↕ Extraction order loaded from /Users/amirali/Desktop/Final Year Project/Final-Year-Project/extractio_order.json
#     models   : 18
#     datasets : 6
#     ⚠ 7 model entries not in this run:
#         · Qwen/Qwen3-1.7B-Base
#         · Qwen/Qwen2.5-3B
#         · google/gemma-3-270m
#         · google/gemma-3-1b-pt
#         · google/gemma-3-4b-pt
#         · … and 2 more
#
# ╔══════════════════════════════════════════════════════════════════════════════════════╗
# ║ HIDDEN STATE EXTRACTION EXPERIMENT                                                   ║
# ╚══════════════════════════════════════════════════════════════════════════════════════╝
#   Experiment ID       : master_v2
#   Device              : cpu
#   Models requested    : 18
#   Datasets            : 6
#   Pooling             : mean
#   Max sequence length : 128
#   Storage dtype       : float32
#   Output root         : /Volumes/Amirali
#   HF cache            : /Volumes/Amirali/.hf_cache/hub
#   Transformers        : 4.57.6
#   PyTorch             : 2.2.2
#
# ────────────────────────────────────────────────────────────────────────────────────────
# SYSTEM / STORAGE REPORT
#   Architecture        : x86_64
#   Logical CPUs        : 8
#   PyTorch threads     : 8
#   PyTorch interop     : 8
#   Python              : 3.12.0
#   RAM total           : 8.00 GiB
#   RAM available       : 0.92 GiB
#   Adaptive reserve    : 0.50 GiB
#   External free       : 1773.41 GiB
#   System fingerprint  : d283165a4730ac5d
#
# ╔══════════════════════════════════════════════════════════════════════════════════════╗
# ║ MODEL 1/18 :: Qwen/Qwen2-0.5B                                                        ║
# ╚══════════════════════════════════════════════════════════════════════════════════════╝
#   Family              : Qwen
#   Generation          : Qwen2
#   Parameters          : 0.5B
#   Architecture        : decoder
#   Training status     : pretrained_base
#   FROZEN batch        : 32
#   Gated               : False
#   Slug folder         : Qwen2-0.5B
#   Repaired isear: labels.npy already compatible, created/upgraded sample_ids.npy (v2), updated extraction.json with v2 fields
#   Updated metadata for isear
#   Repaired tweet_eval_emotion: labels.npy already compatible, created/upgraded sample_ids.npy (v2), updated extraction.json with v2 fields
#   Updated metadata for tweet_eval_emotion
#   Repaired emotion: labels.npy already compatible, created/upgraded sample_ids.npy (v2), updated extraction.json with v2 fields
#   Updated metadata for emotion
# ⚠ Repair failed for goemo: Array can't be memory-mapped: Python objects in dtype.
#   Repaired sst2: labels.npy already compatible, created/upgraded sample_ids.npy (v2)
#   Root            : /Volumes/Amirali ✓
#   HF root         : /Volumes/Amirali/.hf_cache ✓
#   Hub cache       : /Volumes/Amirali/.hf_cache/hub ✓
#   Xet cache       : /Volumes/Amirali/.hf_cache/xet ✓
#   Assets cache    : /Volumes/Amirali/.hf_cache/assets ✓
#
# → Preparing Hugging Face model: Qwen/Qwen2-0.5B
#   Using materialized model tree (offline)
#     Snapshot            : /Volumes/Amirali/models/Qwen2-0.5B
#     Revision            : 91d2aff3f957f99e4c74c962f2f408dcc88a18d8
# `torch_dtype` is deprecated! Use `dtype` instead!
# ────────────────────────────────────────────────────────────────────────────────────────
# MODEL PREFLIGHT
# ────────────────────────────────────────────────────────────────────────────────────────
#   model                             : Qwen/Qwen2-0.5B
#   model_type                        : qwen2
#   architecture                      : decoder
#   dtype                             : torch.float32
#   device                            : cpu
#   layers                            : 24
#   hidden_size                       : 896
#   hidden_states                     : 25
#   max_length                        : 128
#   checkpoint                        : {'active_bytes': 988097824, 'active_gb': 0.920237809419632, 'inventory': {'safetensors': [{'path': '/Volumes/Amirali/models/Qwen2-0.5B/model.safetensors', 'filename': 'model.safetensors', 'size_bytes': 988097824, 'size_gb': 0.920237809419632}], 'pytorch_bin': [], 'index_files': [], 'safetensors_total_bytes': 988097824, 'pytorch_bin_total_bytes': 0}}
#   estimated_loaded_weight_gb        : 1.840475618839264
#   estimated_model_load_peak_gb      : 2.2085707426071166
#   memory                            : {'total_gb': 8.0, 'available_gb': 2.696758270263672, 'used_gb': 4.121036529541016, 'reserve_gb': 0.5393516540527344, 'safe_total_memory_gb': 6.4}
#   status                            : ok
#   ✓ Tokenizer loaded in 4.36s Mode=fast
#   TOKENIZER DIAGNOSTICS
#     class              : Qwen2TokenizerFast
#     vocab size         : 151646
#     pad token          : '<|endoftext|>'
#     pad source         : checkpoint-defined
#     attempts           : [{"mode": "auto_fast", "success": true, "error_type": null, "error": null}]
#
# MODEL LOAD ATTEMPT
#   Attempt              : 1/2
#   Path                 : primary
#   Model                : Qwen/Qwen2-0.5B
#   Snapshot             : /Volumes/Amirali/models/Qwen2-0.5B
#   dtype                : torch.float32
#   device               : cpu
#   SDPA                 : False
#   low_cpu_mem_usage    : True
#   LOADING RESULT
#     Missing keys        : 0
#     Non-core missing    : 0
#     Core missing        : 0
#     Unexpected keys     : 0
#     Mismatched keys     : 0
#     Meta tensors        : 0
#     Core meta           : 0
#     Fatal discrepancy   : False
#   FULL LOADING DIAGNOSTICS
# {
#   "missing_keys": [],
#   "unexpected_keys": [],
#   "mismatched_keys": [],
#   "non_core_missing_keys": [],
#   "core_missing_keys": [],
#   "all_meta_tensors": [],
#   "non_core_meta_tensors": [],
#   "core_meta_tensors": [],
#   "has_meta_tensors": false,
#   "fatal": false
# }
#
# ✓ MODEL READY
#   Load/probe time       : 29.92s
#   Backend               : model_default
#   Model device          : cpu
#   Hidden states         : 25
#   Hidden size           : 896
#   Text-column resolver: canonical 'clean_text'
#
# ────────────────────────────────────────────────────────────────────────────────────────
# DATASET isear
# ────────────────────────────────────────────────────────────────────────────────────────
#   Text column         : clean_text
#   Samples             : 7,532
#   Dataset fingerprint : b3d30f55cf706822307f
#   Hidden layers       : 25
#   Hidden size         : 896
#   Output size est.    : 0.63 GiB
#   Pooling             : mean
#   Max length          : 128
#   FROZEN batch        : 32
#   Device              : cpu
#   Runtime diagnostics : /Volumes/Amirali/hidden_states/Qwen2-0.5B/isear/runtime_state.json
# ✓ DATASET ALREADY COMPLETE (metadata updated): isear
#   Text-column resolver: canonical 'clean_text'
#
# ────────────────────────────────────────────────────────────────────────────────────────
# DATASET tweet_eval_emotion
# ────────────────────────────────────────────────────────────────────────────────────────
#   Text column         : clean_text
#   Samples             : 5,027
#   Dataset fingerprint : 6817361bb24683fa551a
#   Hidden layers       : 25
#   Hidden size         : 896
#   Output size est.    : 0.42 GiB
#   Pooling             : mean
#   Max length          : 128
#   FROZEN batch        : 32
#   Device              : cpu
#   Runtime diagnostics : /Volumes/Amirali/hidden_states/Qwen2-0.5B/tweet_eval_emotion/runtime_state.json
# ✓ DATASET ALREADY COMPLETE (metadata updated): tweet_eval_emotion
#   Text-column resolver: canonical 'clean_text'
#
# ────────────────────────────────────────────────────────────────────────────────────────
# DATASET emotion
# ────────────────────────────────────────────────────────────────────────────────────────
#   Text column         : clean_text
#   Samples             : 19,999
#   Dataset fingerprint : 4dae7a28947f9c017a51
#   Hidden layers       : 25
#   Hidden size         : 896
#   Output size est.    : 1.67 GiB
#   Pooling             : mean
#   Max length          : 128
#   FROZEN batch        : 32
#   Device              : cpu
#   Runtime diagnostics : /Volumes/Amirali/hidden_states/Qwen2-0.5B/emotion/runtime_state.json
# ✓ DATASET ALREADY COMPLETE (metadata updated): emotion
#   Text-column resolver: canonical 'clean_text'
#
# ────────────────────────────────────────────────────────────────────────────────────────
# DATASET goemo
# ────────────────────────────────────────────────────────────────────────────────────────
#   Text column         : clean_text
#   Samples             : 54,039
#   Dataset fingerprint : 1d53da388576cf10b09d
#   Hidden layers       : 25
#   Hidden size         : 896
#   Output size est.    : 4.51 GiB
#   Pooling             : mean
#   Max length          : 128
#   FROZEN batch        : 32
#   Device              : cpu
#   Runtime diagnostics : /Volumes/Amirali/hidden_states/Qwen2-0.5B/goemo/runtime_state.json
# ✓ DATASET ALREADY COMPLETE (metadata updated): goemo
#   Text-column resolver: canonical 'clean_text'
#
# ────────────────────────────────────────────────────────────────────────────────────────
# DATASET sst2
# ────────────────────────────────────────────────────────────────────────────────────────
#   Text column         : clean_text
#   Samples             : 69,676
#   Dataset fingerprint : 2f0ad3fe843618cee06b
#   Hidden layers       : 25
#   Hidden size         : 896
#   Output size est.    : 5.81 GiB
#   Pooling             : mean
#   Max length          : 128
#   FROZEN batch        : 32
#   Device              : cpu
#   Runtime diagnostics : /Volumes/Amirali/hidden_states/Qwen2-0.5B/sst2/runtime_state.json
#   Existing progress   : 35,584/69,676 (51.07%)
#   Incomplete samples  : 34,092
# Python(8897) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# sst2:  51%|#####1    | 35584/69676 [00:00<?, ?sample/s]
# [start] starting with 34092 incomplete samples
#
# ────────────────────────────────────────────────────────────────────────────────────────
# RUNTIME / SPEED TELEMETRY :: sst2
# ────────────────────────────────────────────────────────────────────────────────────────
#   Progress             : 35,648/69,676 (51.16%)
#   Newly computed       : 64
#   Wall time            : 19.66s
#   Throughput           : 3.26 samples/s
#   ETA                  : 2h 54m 11.1s
#   Current stage        : measurement
#
#   LAST BATCH
#     Range              : 35616:35648
#     New samples        : 32
#     Total              : 9.53s
#     Forward            : 9.03s
#     Tokenization       : 0.12s
#     Input transfer     : 0.00s
#     Pooling            : 0.08s
#     Conversion         : 0.00s
#     Memmap write       : 0.11s
#     Flush              : 0.00s
#     Sequence length    : 38
#     Tokens             : 435
#     Token throughput   : 45.67 tokens/s
#
#   ROLLING PERFORMANCE
#     Mean batch         : 9.331s
#     Median batch       : 9.331s
#     P95 batch          : 9.526s
#     Max batch          : 9.526s
#     Slow batches       : 0
#     Current anomaly    : NO
#
#   MEMORY / STORAGE
#     RAM available      : 2.49 GiB
#     Process RSS        : 1.580078125
#     Peak RSS           : 1.58 GiB
#     Minimum RAM        : 2.49 GiB
#     External free      : 1773.41 GiB
#     Successful batches : 2
#     Debug batch output : OFF
# ────────────────────────────────────────────────────────────────────────────────────────
# [runtime] periodic runtime telemetry
#
# ────────────────────────────────────────────────────────────────────────────────────────
# RUNTIME / SPEED TELEMETRY :: sst2
# ────────────────────────────────────────────────────────────────────────────────────────
#   Progress             : 35,712/69,676 (51.25%)
#   Newly computed       : 128
#   Wall time            : 38.01s
#   Throughput           : 3.37 samples/s
#   ETA                  : 2h 48m 04.6s
#   Current stage        : measurement
#
#   LAST BATCH
#     Range              : 35680:35712
#     New samples        : 32
#     Total              : 7.27s
#     Forward            : 6.77s
#     Tokenization       : 0.10s
#     Input transfer     : 0.00s
#     Pooling            : 0.08s
#     Conversion         : 0.00s
#     Memmap write       : 0.13s
#     Flush              : 0.00s
#     Sequence length    : 30
#     Tokens             : 379
#     Token throughput   : 52.14 tokens/s
#
#   ROLLING PERFORMANCE
#     Mean batch         : 9.249s
#     Median batch       : 9.331s
#     P95 batch          : 11.064s
#     Max batch          : 11.064s
#     Slow batches       : 0
#     Current anomaly    : NO
#
#   MEMORY / STORAGE
#     RAM available      : 3.58 GiB
#     Process RSS        : 1.5720634460449219
#     Peak RSS           : 1.58 GiB
#     Minimum RAM        : 2.49 GiB
#     External free      : 1773.41 GiB
#     Successful batches : 4
#     Debug batch output : OFF
# ────────────────────────────────────────────────────────────────────────────────────────
# [runtime] periodic runtime telemetry
#
# ────────────────────────────────────────────────────────────────────────────────────────
# RUNTIME / SPEED TELEMETRY :: sst2
# ────────────────────────────────────────────────────────────────────────────────────────
#   Progress             : 35,776/69,676 (51.35%)
#   Newly computed       : 192
#   Wall time            : 55.39s
#   Throughput           : 3.47 samples/s
#   ETA                  : 2h 42m 59.5s
#   Current stage        : measurement
#
#   LAST BATCH
#     Range              : 35744:35776
#     New samples        : 32
#     Total              : 8.00s
#     Forward            : 7.62s
#     Tokenization       : 0.03s
#     Input transfer     : 0.00s
#     Pooling            : 0.06s
#     Conversion         : 0.00s
#     Memmap write       : 0.12s
#     Flush              : 0.00s
#     Sequence length    : 39
#     Tokens             : 439
#     Token throughput   : 54.89 tokens/s
#
#   ROLLING PERFORMANCE
#     Mean batch         : 9.061s
#     Median batch       : 9.254s
#     P95 batch          : 11.064s
#     Max batch          : 11.064s
#     Slow batches       : 0
#     Current anomaly    : NO
#
#   MEMORY / STORAGE
#     RAM available      : 3.20 GiB
#     Process RSS        : 1.6044654846191406
#     Peak RSS           : 1.60 GiB
#     Minimum RAM        : 2.49 GiB
#     External free      : 1773.41 GiB
#     Successful batches : 6
#     Debug batch output : OFF
# ────────────────────────────────────────────────────────────────────────────────────────
# [runtime] periodic runtime telemetry
#
# ────────────────────────────────────────────────────────────────────────────────────────
# RUNTIME / SPEED TELEMETRY :: sst2
# ────────────────────────────────────────────────────────────────────────────────────────
#   Progress             : 35,840/69,676 (51.44%)
#   Newly computed       : 256
#   Wall time            : 1m 15.6s
#   Throughput           : 3.39 samples/s
#   ETA                  : 2h 46m 31.0s
#   Current stage        : measurement
#
#   LAST BATCH
#     Range              : 35808:35840
#     New samples        : 32
#     Total              : 12.51s
#     Forward            : 11.70s
#     Tokenization       : 0.03s
#     Input transfer     : 0.00s
#     Pooling            : 0.10s
#     Conversion         : 0.00s
#     Memmap write       : 0.41s
#     Flush              : 0.00s
#     Sequence length    : 57
#     Tokens             : 404
#     Token throughput   : 32.29 tokens/s
#
#   ROLLING PERFORMANCE
#     Mean batch         : 9.319s
#     Median batch       : 9.254s
#     P95 batch          : 12.513s
#     Max batch          : 12.513s
#     Slow batches       : 0
#     Current anomaly    : NO
#
#   MEMORY / STORAGE
#     RAM available      : 2.98 GiB
#     Process RSS        : 1.6655464172363281
#     Peak RSS           : 1.67 GiB
#     Minimum RAM        : 2.49 GiB
#     External free      : 1773.41 GiB
#     Successful batches : 8
#     Debug batch output : OFF
# ────────────────────────────────────────────────────────────────────────────────────────
# [runtime] periodic runtime telemetry
#
# ────────────────────────────────────────────────────────────────────────────────────────
# RUNTIME / SPEED TELEMETRY :: sst2
# ────────────────────────────────────────────────────────────────────────────────────────
#   Progress             : 35,904/69,676 (51.53%)
#   Newly computed       : 320
#   Wall time            : 1m 31.6s
#   Throughput           : 3.50 samples/s
#   ETA                  : 2h 41m 02.4s
#   Current stage        : measurement
#
#   LAST BATCH
#     Range              : 35872:35904
#     New samples        : 32
#     Total              : 8.07s
#     Forward            : 7.70s
#     Tokenization       : 0.02s
#     Input transfer     : 0.00s
#     Pooling            : 0.06s
#     Conversion         : 0.00s
#     Memmap write       : 0.12s
#     Flush              : 0.00s
#     Sequence length    : 40
#     Tokens             : 323
#     Token throughput   : 40.03 tokens/s
#
#   ROLLING PERFORMANCE
#     Mean batch         : 9.050s
#     Median batch       : 8.603s
#     P95 batch          : 12.513s
#     Max batch          : 12.513s
#     Slow batches       : 0
#     Current anomaly    : NO
#
#   MEMORY / STORAGE
#     RAM available      : 2.69 GiB
#     Process RSS        : 1.6289253234863281
#     Peak RSS           : 1.67 GiB
#     Minimum RAM        : 2.49 GiB
#     External free      : 1773.41 GiB
#     Successful batches : 10
#     Debug batch output : OFF
# ────────────────────────────────────────────────────────────────────────────────────────
# [runtime] periodic runtime telemetry
#
# ────────────────────────────────────────────────────────────────────────────────────────
# RUNTIME / SPEED TELEMETRY :: sst2
# ────────────────────────────────────────────────────────────────────────────────────────
#   Progress             : 36,000/69,676 (51.67%)
#   Newly computed       : 416
#   Wall time            : 1m 54.3s
#   Throughput           : 3.64 samples/s
#   ETA                  : 2h 34m 13.7s
#   Current stage        : measurement
#
#   LAST BATCH
#     Range              : 35968:36000
#     New samples        : 32
#     Total              : 8.19s
#     Forward            : 7.89s
#     Tokenization       : 0.01s
#     Input transfer     : 0.00s
#     Pooling            : 0.06s
#     Conversion         : 0.00s
#     Memmap write       : 0.04s
#     Flush              : 0.00s
#     Sequence length    : 36
#     Tokens             : 229
#     Token throughput   : 27.96 tokens/s
#
#   ROLLING PERFORMANCE
#     Mean batch         : 8.710s
#     Median batch       : 8.189s
#     P95 batch          : 12.513s
#     Max batch          : 12.513s
#     Slow batches       : 0
#     Current anomaly    : NO
#
#   MEMORY / STORAGE
#     RAM available      : 2.77 GiB
#     Process RSS        : 1.6269645690917969
#     Peak RSS           : 1.67 GiB
#     Minimum RAM        : 2.49 GiB
#     External free      : 1773.41 GiB
#     Successful batches : 13
#     Debug batch output : OFF
# ────────────────────────────────────────────────────────────────────────────────────────
# [runtime] periodic runtime telemetry
#
# ────────────────────────────────────────────────────────────────────────────────────────
# RUNTIME / SPEED TELEMETRY :: sst2
# ────────────────────────────────────────────────────────────────────────────────────────
#   Progress             : 36,064/69,676 (51.76%)
#   Newly computed       : 480
#   Wall time            : 2m 10.0s
#   Throughput           : 3.69 samples/s
#   ETA                  : 2h 31m 39.9s
#   Current stage        : measurement
#
#   LAST BATCH
#     Range              : 36032:36064
#     New samples        : 32
#     Total              : 8.29s
#     Forward            : 7.85s
#     Tokenization       : 0.01s
#     Input transfer     : 0.00s
#     Pooling            : 0.10s
#     Conversion         : 0.00s
#     Memmap write       : 0.09s
#     Flush              : 0.00s
#     Sequence length    : 37
#     Tokens             : 418
#     Token throughput   : 50.40 tokens/s
#
#   ROLLING PERFORMANCE
#     Mean batch         : 8.590s
#     Median batch       : 8.189s
#     P95 batch          : 12.513s
#     Max batch          : 12.513s
#     Slow batches       : 0
#     Current anomaly    : NO
#
#   MEMORY / STORAGE
#     RAM available      : 2.47 GiB
#     Process RSS        : 1.5769767761230469
#     Peak RSS           : 1.67 GiB
#     Minimum RAM        : 2.47 GiB
#     External free      : 1773.41 GiB
#     Successful batches : 15
#     Debug batch output : OFF
# ────────────────────────────────────────────────────────────────────────────────────────
# [runtime] periodic runtime telemetry
#
# ────────────────────────────────────────────────────────────────────────────────────────
# RUNTIME / SPEED TELEMETRY :: sst2
# ────────────────────────────────────────────────────────────────────────────────────────
#   Progress             : 36,160/69,676 (51.90%)
#   Newly computed       : 576
#   Wall time            : 2m 29.2s
#   Throughput           : 3.86 samples/s
#   ETA                  : 2h 24m 43.1s
#   Current stage        : measurement
#
#   LAST BATCH
#     Range              : 36128:36160
#     New samples        : 32
#     Total              : 5.19s
#     Forward            : 4.78s
#     Tokenization       : 0.02s
#     Input transfer     : 0.00s
#     Pooling            : 0.03s
#     Conversion         : 0.00s
#     Memmap write       : 0.26s
#     Flush              : 0.00s
#     Sequence length    : 29
#     Tokens             : 286
#     Token throughput   : 55.06 tokens/s
#
#   ROLLING PERFORMANCE
#     Mean batch         : 8.228s
#     Median batch       : 8.130s
#     P95 batch          : 12.513s
#     Max batch          : 12.513s
#     Slow batches       : 0
#     Current anomaly    : NO
#
#   MEMORY / STORAGE
#     RAM available      : 3.29 GiB
#     Process RSS        : 1.5673599243164062
#     Peak RSS           : 1.67 GiB
#     Minimum RAM        : 2.47 GiB
#     External free      : 1773.41 GiB
#     Successful batches : 18
#     Debug batch output : OFF
# ────────────────────────────────────────────────────────────────────────────────────────
# [runtime] periodic runtime telemetry
#
# ────────────────────────────────────────────────────────────────────────────────────────
# RUNTIME / SPEED TELEMETRY :: sst2
# ────────────────────────────────────────────────────────────────────────────────────────
#   Progress             : 36,256/69,676 (52.04%)
#   Newly computed       : 672
#   Wall time            : 2m 49.7s
#   Throughput           : 3.96 samples/s
#   ETA                  : 2h 20m 41.8s
#   Current stage        : measurement
#
#   LAST BATCH
#     Range              : 36224:36256
#     New samples        : 32
#     Total              : 7.50s
#     Forward            : 6.82s
#     Tokenization       : 0.05s
#     Input transfer     : 0.00s
#     Pooling            : 0.08s
#     Conversion         : 0.00s
#     Memmap write       : 0.10s
#     Flush              : 0.01s
#     Sequence length    : 30
#     Tokens             : 339
#     Token throughput   : 45.18 tokens/s
#
#   ROLLING PERFORMANCE
#     Mean batch         : 7.970s
#     Median batch       : 7.937s
#     P95 batch          : 11.064s
#     Max batch          : 12.513s
#     Slow batches       : 0
#     Current anomaly    : NO
#
#   MEMORY / STORAGE
#     RAM available      : 2.77 GiB
#     Process RSS        : 1.5604133605957031
#     Peak RSS           : 1.67 GiB
#     Minimum RAM        : 2.47 GiB
#     External free      : 1773.40 GiB
#     Successful batches : 21
#     Debug batch output : OFF
# ────────────────────────────────────────────────────────────────────────────────────────
# [runtime] periodic runtime telemetry
#
# ────────────────────────────────────────────────────────────────────────────────────────
# RUNTIME / SPEED TELEMETRY :: sst2
# ────────────────────────────────────────────────────────────────────────────────────────
#   Progress             : 36,320/69,676 (52.13%)
#   Newly computed       : 736
#   Wall time            : 3m 07.4s
#   Throughput           : 3.93 samples/s
#   ETA                  : 2h 21m 32.3s
#   Current stage        : measurement
#
#   LAST BATCH
#     Range              : 36288:36320
#     New samples        : 32
#     Total              : 8.82s
#     Forward            : 8.35s
#     Tokenization       : 0.03s
#     Input transfer     : 0.00s
#     Pooling            : 0.09s
#     Conversion         : 0.00s
#     Memmap write       : 0.10s
#     Flush              : 0.00s
#     Sequence length    : 36
#     Tokens             : 412
#     Token throughput   : 46.70 tokens/s
#
#   ROLLING PERFORMANCE
#     Mean batch         : 7.821s
#     Median batch       : 7.937s
#     P95 batch          : 9.372s
#     Max batch          : 12.513s
#     Slow batches       : 0
#     Current anomaly    : NO
#
#   MEMORY / STORAGE
#     RAM available      : 3.18 GiB
#     Process RSS        : 1.5861015319824219
#     Peak RSS           : 1.67 GiB
#     Minimum RAM        : 2.47 GiB
#     External free      : 1773.40 GiB
#     Successful batches : 23
#     Debug batch output : OFF
# ────────────────────────────────────────────────────────────────────────────────────────
# [runtime] periodic runtime telemetry
#
# ────────────────────────────────────────────────────────────────────────────────────────
# RUNTIME / SPEED TELEMETRY :: sst2
# ────────────────────────────────────────────────────────────────────────────────────────
#   Progress             : 36,416/69,676 (52.26%)
#   Newly computed       : 832
#   Wall time            : 3m 29.8s
#   Throughput           : 3.97 samples/s
#   ETA                  : 2h 19m 46.2s
#   Current stage        : measurement
#
#   LAST BATCH
#     Range              : 36384:36416
#     New samples        : 32
#     Total              : 7.56s
#     Forward            : 7.23s
#     Tokenization       : 0.02s
#     Input transfer     : 0.00s
#     Pooling            : 0.06s
#     Conversion         : 0.00s
#     Memmap write       : 0.08s
#     Flush              : 0.00s
#     Sequence length    : 35
#     Tokens             : 306
#     Token throughput   : 40.48 tokens/s
#
#   ROLLING PERFORMANCE
#     Mean batch         : 7.708s
#     Median batch       : 7.713s
#     P95 batch          : 8.822s
#     Max batch          : 12.513s
#     Slow batches       : 0
#     Current anomaly    : NO
#
#   MEMORY / STORAGE
#     RAM available      : 2.91 GiB
#     Process RSS        : 1.5951576232910156
#     Peak RSS           : 1.67 GiB
#     Minimum RAM        : 2.47 GiB
#     External free      : 1773.40 GiB
#     Successful batches : 26
#     Debug batch output : OFF
# ────────────────────────────────────────────────────────────────────────────────────────
# [runtime] periodic runtime telemetry
#
# ────────────────────────────────────────────────────────────────────────────────────────
# RUNTIME / SPEED TELEMETRY :: sst2
# ────────────────────────────────────────────────────────────────────────────────────────
#   Progress             : 36,480/69,676 (52.36%)
#   Newly computed       : 896
#   Wall time            : 3m 49.6s
#   Throughput           : 3.90 samples/s
#   ETA                  : 2h 21m 47.6s
#   Current stage        : measurement
#
#   LAST BATCH
#     Range              : 36448:36480
#     New samples        : 32
#     Total              : 11.06s
#     Forward            : 10.72s
#     Tokenization       : 0.03s
#     Input transfer     : 0.00s
#     Pooling            : 0.06s
#     Conversion         : 0.00s
#     Memmap write       : 0.08s
#     Flush              : 0.01s
#     Sequence length    : 48
#     Tokens             : 372
#     Token throughput   : 33.63 tokens/s
#
#   ROLLING PERFORMANCE
#     Mean batch         : 7.691s
#     Median batch       : 7.812s
#     P95 batch          : 8.822s
#     Max batch          : 11.062s
#     Slow batches       : 0
#     Current anomaly    : NO
#
#   MEMORY / STORAGE
#     RAM available      : 2.90 GiB
#     Process RSS        : 1.6406822204589844
#     Peak RSS           : 1.67 GiB
#     Minimum RAM        : 2.47 GiB
#     External free      : 1773.40 GiB
#     Successful batches : 28
#     Debug batch output : OFF
# ────────────────────────────────────────────────────────────────────────────────────────
# [runtime] periodic runtime telemetry
#
# ────────────────────────────────────────────────────────────────────────────────────────
# RUNTIME / SPEED TELEMETRY :: sst2
# ────────────────────────────────────────────────────────────────────────────────────────
#   Progress             : 36,544/69,676 (52.45%)
#   Newly computed       : 960
#   Wall time            : 4m 06.2s
#   Throughput           : 3.90 samples/s
#   ETA                  : 2h 21m 38.5s
#   Current stage        : measurement
#
#   LAST BATCH
#     Range              : 36512:36544
#     New samples        : 32
#     Total              : 7.02s
#     Forward            : 6.62s
#     Tokenization       : 0.02s
#     Input transfer     : 0.00s
#     Pooling            : 0.08s
#     Conversion         : 0.00s
#     Memmap write       : 0.09s
#     Flush              : 0.00s
#     Sequence length    : 34
#     Tokens             : 335
#     Token throughput   : 47.74 tokens/s
#
#   ROLLING PERFORMANCE
#     Mean batch         : 7.723s
#     Median batch       : 7.681s
#     P95 batch          : 9.576s
#     Max batch          : 11.062s
#     Slow batches       : 0
#     Current anomaly    : NO
#
#   MEMORY / STORAGE
#     RAM available      : 2.82 GiB
#     Process RSS        : 1.6134605407714844
#     Peak RSS           : 1.67 GiB
#     Minimum RAM        : 2.47 GiB
#     External free      : 1773.40 GiB
#     Successful batches : 30
#     Debug batch output : OFF
# ────────────────────────────────────────────────────────────────────────────────────────
# [runtime] periodic runtime telemetry
#
# ────────────────────────────────────────────────────────────────────────────────────────
# RUNTIME / SPEED TELEMETRY :: sst2
# ────────────────────────────────────────────────────────────────────────────────────────
#   Progress             : 36,608/69,676 (52.54%)
#   Newly computed       : 1,024
#   Wall time            : 4m 28.4s
#   Throughput           : 3.82 samples/s
#   ETA                  : 2h 24m 27.3s
#   Current stage        : measurement
#
#   LAST BATCH
#     Range              : 36576:36608
#     New samples        : 32
#     Total              : 9.09s
#     Forward            : 8.46s
#     Tokenization       : 0.02s
#     Input transfer     : 0.00s
#     Pooling            : 0.08s
#     Conversion         : 0.00s
#     Memmap write       : 0.33s
#     Flush              : 0.01s
#     Sequence length    : 43
#     Tokens             : 373
#     Token throughput   : 41.02 tokens/s
#
#   ROLLING PERFORMANCE
#     Mean batch         : 8.102s
#     Median batch       : 7.968s
#     P95 batch          : 11.062s
#     Max batch          : 13.028s
#     Slow batches       : 0
#     Current anomaly    : NO
#
#   MEMORY / STORAGE
#     RAM available      : 2.66 GiB
#     Process RSS        : 1.6308746337890625
#     Peak RSS           : 1.67 GiB
#     Minimum RAM        : 2.47 GiB
#     External free      : 1773.40 GiB
#     Successful batches : 32
#     Debug batch output : OFF
# ────────────────────────────────────────────────────────────────────────────────────────
# [runtime] periodic runtime telemetry
#
# ────────────────────────────────────────────────────────────────────────────────────────
# RUNTIME / SPEED TELEMETRY :: sst2
# ────────────────────────────────────────────────────────────────────────────────────────
#   Progress             : 36,672/69,676 (52.63%)
#   Newly computed       : 1,088
#   Wall time            : 4m 46.8s
#   Throughput           : 3.79 samples/s
#   ETA                  : 2h 25m 00.8s
#   Current stage        : measurement
#
#   LAST BATCH
#     Range              : 36640:36672
#     New samples        : 32
#     Total              : 6.79s
#     Forward            : 6.50s
#     Tokenization       : 0.02s
#     Input transfer     : 0.00s
#     Pooling            : 0.06s
#     Conversion         : 0.00s
#     Memmap write       : 0.03s
#     Flush              : 0.00s
#     Sequence length    : 30
#     Tokens             : 339
#     Token throughput   : 49.91 tokens/s
#
#   ROLLING PERFORMANCE
#     Mean batch         : 8.246s
#     Median batch       : 7.988s
#     P95 batch          : 11.600s
#     Max batch          : 13.028s
#     Slow batches       : 0
#     Current anomaly    : NO
#
#   MEMORY / STORAGE
#     RAM available      : 2.70 GiB
#     Process RSS        : 1.6007614135742188
#     Peak RSS           : 1.67 GiB
#     Minimum RAM        : 2.47 GiB
#     External free      : 1773.40 GiB
#     Successful batches : 34
#     Debug batch output : OFF
# ────────────────────────────────────────────────────────────────────────────────────────
# [runtime] periodic runtime telemetry
#
# ────────────────────────────────────────────────────────────────────────────────────────
# RUNTIME / SPEED TELEMETRY :: sst2
# ────────────────────────────────────────────────────────────────────────────────────────
#   Progress             : 36,736/69,676 (52.72%)
#   Newly computed       : 1,152
#   Wall time            : 5m 04.7s
#   Throughput           : 3.78 samples/s
#   ETA                  : 2h 25m 12.1s
#   Current stage        : measurement
#
#   LAST BATCH
#     Range              : 36704:36736
#     New samples        : 32
#     Total              : 9.04s
#     Forward            : 8.50s
#     Tokenization       : 0.07s
#     Input transfer     : 0.00s
#     Pooling            : 0.10s
#     Conversion         : 0.00s
#     Memmap write       : 0.12s
#     Flush              : 0.01s
#     Sequence length    : 39
#     Tokens             : 407
#     Token throughput   : 45.03 tokens/s
#
#   ROLLING PERFORMANCE
#     Mean batch         : 8.312s
#     Median batch       : 8.260s
#     P95 batch          : 11.600s
#     Max batch          : 13.028s
#     Slow batches       : 0
#     Current anomaly    : NO
#
#   MEMORY / STORAGE
#     RAM available      : 3.48 GiB
#     Process RSS        : 1.6336822509765625
#     Peak RSS           : 1.67 GiB
#     Minimum RAM        : 2.47 GiB
#     External free      : 1773.40 GiB
#     Successful batches : 36
#     Debug batch output : OFF
# ────────────────────────────────────────────────────────────────────────────────────────
# [runtime] periodic runtime telemetry
#
# ────────────────────────────────────────────────────────────────────────────────────────
# RUNTIME / SPEED TELEMETRY :: sst2
# ────────────────────────────────────────────────────────────────────────────────────────
#   Progress             : 36,832/69,676 (52.86%)
#   Newly computed       : 1,248
#   Wall time            : 5m 26.8s
#   Throughput           : 3.82 samples/s
#   ETA                  : 2h 23m 19.7s
#   Current stage        : measurement
#
#   LAST BATCH
#     Range              : 36800:36832
#     New samples        : 32
#     Total              : 8.59s
#     Forward            : 8.11s
#     Tokenization       : 0.02s
#     Input transfer     : 0.00s
#     Pooling            : 0.04s
#     Conversion         : 0.00s
#     Memmap write       : 0.22s
#     Flush              : 0.00s
#     Sequence length    : 31
#     Tokens             : 329
#     Token throughput   : 38.31 tokens/s
#
#   ROLLING PERFORMANCE
#     Mean batch         : 8.595s
#     Median batch       : 8.681s
#     P95 batch          : 11.600s
#     Max batch          : 13.028s
#     Slow batches       : 0
#     Current anomaly    : NO
#
#   MEMORY / STORAGE
#     RAM available      : 1.81 GiB
#     Process RSS        : 1.3406410217285156
#     Peak RSS           : 1.67 GiB
#     Minimum RAM        : 1.81 GiB
#     External free      : 1773.40 GiB
#     Successful batches : 39
#     Debug batch output : OFF
# ────────────────────────────────────────────────────────────────────────────────────────
# [runtime] periodic runtime telemetry
#
# ────────────────────────────────────────────────────────────────────────────────────────
# RUNTIME / SPEED TELEMETRY :: sst2
# ────────────────────────────────────────────────────────────────────────────────────────
#   Progress             : 36,896/69,676 (52.95%)
#   Newly computed       : 1,312
#   Wall time            : 5m 48.0s
#   Throughput           : 3.77 samples/s
#   ETA                  : 2h 24m 54.3s
#   Current stage        : measurement
#
#   LAST BATCH
#     Range              : 36864:36896
#     New samples        : 32
#     Total              : 11.71s
#     Forward            : 10.96s
#     Tokenization       : 0.26s
#     Input transfer     : 0.00s
#     Pooling            : 0.09s
#     Conversion         : 0.00s
#     Memmap write       : 0.09s
#     Flush              : 0.00s
#     Sequence length    : 42
#     Tokens             : 413
#     Token throughput   : 35.28 tokens/s
#
#   ROLLING PERFORMANCE
#     Mean batch         : 8.896s
#     Median batch       : 8.799s
#     P95 batch          : 11.706s
#     Max batch          : 13.028s
#     Slow batches       : 0
#     Current anomaly    : NO
#
#   MEMORY / STORAGE
#     RAM available      : 1.74 GiB
#     Process RSS        : 0.6289520263671875
#     Peak RSS           : 1.67 GiB
#     Minimum RAM        : 1.74 GiB
#     External free      : 1773.40 GiB
#     Successful batches : 41
#     Debug batch output : OFF
# ────────────────────────────────────────────────────────────────────────────────────────
# [runtime] periodic runtime telemetry
#
# ────────────────────────────────────────────────────────────────────────────────────────
# RUNTIME / SPEED TELEMETRY :: sst2
# ────────────────────────────────────────────────────────────────────────────────────────
#   Progress             : 36,960/69,676 (53.05%)
#   Newly computed       : 1,376
#   Wall time            : 6m 10.0s
#   Throughput           : 3.72 samples/s
#   ETA                  : 2h 26m 36.4s
#   Current stage        : measurement
#
#   LAST BATCH
#     Range              : 36928:36960
#     New samples        : 32
#     Total              : 11.52s
#     Forward            : 10.14s
#     Tokenization       : 0.40s
#     Input transfer     : 0.00s
#     Pooling            : 0.30s
#     Conversion         : 0.00s
#     Memmap write       : 0.17s
#     Flush              : 0.01s
#     Sequence length    : 30
#     Tokens             : 354
#     Token throughput   : 30.72 tokens/s
#
#   ROLLING PERFORMANCE
#     Mean batch         : 9.104s
#     Median batch       : 8.920s
#     P95 batch          : 11.706s
#     Max batch          : 13.028s
#     Slow batches       : 0
#     Current anomaly    : NO
#
#   MEMORY / STORAGE
#     RAM available      : 1.69 GiB
#     Process RSS        : 0.7892608642578125
#     Peak RSS           : 1.67 GiB
#     Minimum RAM        : 1.69 GiB
#     External free      : 1773.40 GiB
#     Successful batches : 43
#     Debug batch output : OFF
# ────────────────────────────────────────────────────────────────────────────────────────
# [runtime] periodic runtime telemetry
#
# ────────────────────────────────────────────────────────────────────────────────────────
# RUNTIME / SPEED TELEMETRY :: sst2
# ────────────────────────────────────────────────────────────────────────────────────────
#   Progress             : 36,992/69,676 (53.09%)
#   Newly computed       : 1,408
#   Wall time            : 6m 37.6s
#   Throughput           : 3.54 samples/s
#   ETA                  : 2h 33m 49.0s
#   Current stage        : measurement
#
#   LAST BATCH
#     Range              : 36960:36992
#     New samples        : 32
#     Total              : 27.18s
#     Forward            : 25.44s
#     Tokenization       : 0.75s
#     Input transfer     : 0.00s
#     Pooling            : 0.14s
#     Conversion         : 0.00s
#     Memmap write       : 0.18s
#     Flush              : 0.00s
#     Sequence length    : 41
#     Tokens             : 326
#     Token throughput   : 11.99 tokens/s
#
#   ROLLING PERFORMANCE
#     Mean batch         : 10.110s
#     Median batch       : 9.066s
#     P95 batch          : 13.028s
#     Max batch          : 27.185s
#     Slow batches       : 1
#     Current anomaly    : YES (x3.00)
#
#   MEMORY / STORAGE
#     RAM available      : 0.64 GiB
#     Process RSS        : 0.1851348876953125
#     Peak RSS           : 1.67 GiB
#     Minimum RAM        : 0.64 GiB
#     External free      : 1773.40 GiB
#     Successful batches : 44
#     Debug batch output : OFF
# ────────────────────────────────────────────────────────────────────────────────────────
# [runtime] periodic runtime telemetry
#
# ────────────────────────────────────────────────────────────────────────────────────────
# RUNTIME / SPEED TELEMETRY :: sst2
# ────────────────────────────────────────────────────────────────────────────────────────
#   Progress             : 37,024/69,676 (53.14%)
#   Newly computed       : 1,440
#   Wall time            : 7m 02.9s
#   Throughput           : 3.41 samples/s
#   ETA                  : 2h 39m 48.8s
#   Current stage        : measurement
#
#   LAST BATCH
#     Range              : 36992:37024
#     New samples        : 32
#     Total              : 24.75s
#     Forward            : 21.97s
#     Tokenization       : 1.23s
#     Input transfer     : 0.00s
#     Pooling            : 0.26s
#     Conversion         : 0.00s
#     Memmap write       : 0.25s
#     Flush              : 0.00s
#     Sequence length    : 29
#     Tokens             : 251
#     Token throughput   : 10.14 tokens/s
#
#   ROLLING PERFORMANCE
#     Mean batch         : 10.960s
#     Median batch       : 9.260s
#     P95 batch          : 24.752s
#     Max batch          : 27.185s
#     Slow batches       : 2
#     Current anomaly    : YES (x2.67)
#
#   MEMORY / STORAGE
#     RAM available      : 1.18 GiB
#     Process RSS        : 0.29747772216796875
#     Peak RSS           : 1.67 GiB
#     Minimum RAM        : 0.64 GiB
#     External free      : 1773.40 GiB
#     Successful batches : 45
#     Debug batch output : OFF
# ────────────────────────────────────────────────────────────────────────────────────────
# [runtime] periodic runtime telemetry
#
# ────────────────────────────────────────────────────────────────────────────────────────
# RUNTIME / SPEED TELEMETRY :: sst2
# ────────────────────────────────────────────────────────────────────────────────────────
#   Progress             : 37,056/69,676 (53.18%)
#   Newly computed       : 1,472
#   Wall time            : 7m 28.6s
#   Throughput           : 3.28 samples/s
#   ETA                  : 2h 45m 40.4s
#   Current stage        : measurement
#
#   LAST BATCH
#     Range              : 37024:37056
#     New samples        : 32
#     Total              : 25.50s
#     Forward            : 24.00s
#     Tokenization       : 0.92s
#     Input transfer     : 0.00s
#     Pooling            : 0.07s
#     Conversion         : 0.00s
#     Memmap write       : 0.05s
#     Flush              : 0.00s
#     Sequence length    : 35
#     Tokens             : 319
#     Token throughput   : 12.51 tokens/s
#
#   ROLLING PERFORMANCE
#     Mean batch         : 11.857s
#     Median batch       : 9.502s
#     P95 batch          : 25.500s
#     Max batch          : 27.185s
#     Slow batches       : 3
#     Current anomaly    : YES (x2.68)
#
#   MEMORY / STORAGE
#     RAM available      : 0.89 GiB
#     Process RSS        : 0.31656646728515625
#     Peak RSS           : 1.67 GiB
#     Minimum RAM        : 0.64 GiB
#     External free      : 1773.40 GiB
#     Successful batches : 46
#     Debug batch output : OFF
# ────────────────────────────────────────────────────────────────────────────────────────
# [runtime] periodic runtime telemetry
#
# ────────────────────────────────────────────────────────────────────────────────────────
# RUNTIME / SPEED TELEMETRY :: sst2
# ────────────────────────────────────────────────────────────────────────────────────────
#   Progress             : 37,088/69,676 (53.23%)
#   Newly computed       : 1,504
#   Wall time            : 8m 00.9s
#   Throughput           : 3.13 samples/s
#   ETA                  : 2h 53m 39.0s
#   Current stage        : measurement
#
#   LAST BATCH
#     Range              : 37056:37088
#     New samples        : 32
#     Total              : 31.97s
#     Forward            : 29.41s
#     Tokenization       : 1.10s
#     Input transfer     : 0.00s
#     Pooling            : 0.10s
#     Conversion         : 0.00s
#     Memmap write       : 0.42s
#     Flush              : 0.00s
#     Sequence length    : 38
#     Tokens             : 339
#     Token throughput   : 10.60 tokens/s
#
#   ROLLING PERFORMANCE
#     Mean batch         : 13.017s
#     Median batch       : 9.921s
#     P95 batch          : 27.185s
#     Max batch          : 31.972s
#     Slow batches       : 4
#     Current anomaly    : YES (x3.22)
#
#   MEMORY / STORAGE
#     RAM available      : 1.09 GiB
#     Process RSS        : 0.2777824401855469
#     Peak RSS           : 1.67 GiB
#     Minimum RAM        : 0.64 GiB
#     External free      : 1773.40 GiB
#     Successful batches : 47
#     Debug batch output : OFF
# ────────────────────────────────────────────────────────────────────────────────────────
# [runtime] periodic runtime telemetry
#
# ────────────────────────────────────────────────────────────────────────────────────────
# RUNTIME / SPEED TELEMETRY :: sst2
# ────────────────────────────────────────────────────────────────────────────────────────
#   Progress             : 37,120/69,676 (53.28%)
#   Newly computed       : 1,536
#   Wall time            : 8m 24.7s
#   Throughput           : 3.04 samples/s
#   ETA                  : 2h 58m 16.6s
#   Current stage        : measurement
#
#   LAST BATCH
#     Range              : 37088:37120
#     New samples        : 32
#     Total              : 23.61s
#     Forward            : 20.87s
#     Tokenization       : 0.73s
#     Input transfer     : 0.00s
#     Pooling            : 0.14s
#     Conversion         : 0.00s
#     Memmap write       : 0.24s
#     Flush              : 0.00s
#     Sequence length    : 30
#     Tokens             : 332
#     Token throughput   : 14.06 tokens/s
#
#   ROLLING PERFORMANCE
#     Mean batch         : 13.645s
#     Median batch       : 9.921s
#     P95 batch          : 27.185s
#     Max batch          : 31.972s
#     Slow batches       : 5
#     Current anomaly    : YES (x2.38)
#
#   MEMORY / STORAGE
#     RAM available      : 0.95 GiB
#     Process RSS        : 0.15948486328125
#     Peak RSS           : 1.67 GiB
#     Minimum RAM        : 0.64 GiB
#     External free      : 1773.40 GiB
#     Successful batches : 48
#     Debug batch output : OFF
# ────────────────────────────────────────────────────────────────────────────────────────
# [runtime] periodic runtime telemetry
#
# ────────────────────────────────────────────────────────────────────────────────────────
# RUNTIME / SPEED TELEMETRY :: sst2
# ────────────────────────────────────────────────────────────────────────────────────────
#   Progress             : 37,152/69,676 (53.32%)
#   Newly computed       : 1,568
#   Wall time            : 8m 45.1s
#   Throughput           : 2.99 samples/s
#   ETA                  : 3h 1m 31.2s
#   Current stage        : measurement
#
#   LAST BATCH
#     Range              : 37120:37152
#     New samples        : 32
#     Total              : 20.23s
#     Forward            : 18.38s
#     Tokenization       : 1.14s
#     Input transfer     : 0.00s
#     Pooling            : 0.07s
#     Conversion         : 0.00s
#     Memmap write       : 0.06s
#     Flush              : 0.00s
#     Sequence length    : 37
#     Tokens             : 385
#     Token throughput   : 19.03 tokens/s
#
#   ROLLING PERFORMANCE
#     Mean batch         : 14.178s
#     Median batch       : 10.894s
#     P95 batch          : 27.185s
#     Max batch          : 31.972s
#     Slow batches       : 5
#     Current anomaly    : NO
#
#   MEMORY / STORAGE
#     RAM available      : 1.86 GiB
#     Process RSS        : 0.6961135864257812
#     Peak RSS           : 1.67 GiB
#     Minimum RAM        : 0.64 GiB
#     External free      : 1773.40 GiB
#     Successful batches : 49
#     Debug batch output : OFF
# ────────────────────────────────────────────────────────────────────────────────────────
# [runtime] periodic runtime telemetry
#
# ────────────────────────────────────────────────────────────────────────────────────────
# RUNTIME / SPEED TELEMETRY :: sst2
# ────────────────────────────────────────────────────────────────────────────────────────
#   Progress             : 37,184/69,676 (53.37%)
#   Newly computed       : 1,600
#   Wall time            : 9m 03.8s
#   Throughput           : 2.94 samples/s
#   ETA                  : 3h 4m 03.2s
#   Current stage        : measurement
#
#   LAST BATCH
#     Range              : 37152:37184
#     New samples        : 32
#     Total              : 18.64s
#     Forward            : 16.74s
#     Tokenization       : 1.23s
#     Input transfer     : 0.00s
#     Pooling            : 0.09s
#     Conversion         : 0.00s
#     Memmap write       : 0.10s
#     Flush              : 0.02s
#     Sequence length    : 55
#     Tokens             : 418
#     Token throughput   : 22.42 tokens/s
#
#   ROLLING PERFORMANCE
#     Mean batch         : 14.759s
#     Median batch       : 11.561s
#     P95 batch          : 27.185s
#     Max batch          : 31.972s
#     Slow batches       : 5
#     Current anomaly    : NO
#
#   MEMORY / STORAGE
#     RAM available      : 2.02 GiB
#     Process RSS        : 0.9150390625
#     Peak RSS           : 1.67 GiB
#     Minimum RAM        : 0.64 GiB
#     External free      : 1773.40 GiB
#     Successful batches : 50
#     Debug batch output : OFF
# ────────────────────────────────────────────────────────────────────────────────────────
# [runtime] periodic runtime telemetry
#
# ────────────────────────────────────────────────────────────────────────────────────────
# RUNTIME / SPEED TELEMETRY :: sst2
# ────────────────────────────────────────────────────────────────────────────────────────
#   Progress             : 37,216/69,676 (53.41%)
#   Newly computed       : 1,632
#   Wall time            : 9m 22.2s
#   Throughput           : 2.90 samples/s
#   ETA                  : 3h 6m 22.0s
# ...
# RUNTIME / SPEED TELEMETRY :: sst2
# ────────────────────────────────────────────────────────────────────────────────────────
#   Progress             : 38,432/69,676 (55.16%)
#   Newly computed       : 2,848
#   Wall time            : 13m 49.7s
#   Throughput           : 3.43 samples/s
#   ETA                  : 2h 31m 42.2s
#   Current stage        : measurement
#
#   LAST BATCH
#     Range              : 38400:38432
#     New samples        : 32
#     Total              : 8.36s
#     Forward            : 8.06s
#     Tokenization       : 0.01s
#     Input transfer     : 0.00s
#     Pooling            : 0.04s
#     Conversion         : 0.00s
#     Memmap write       : 0.14s
#     Flush              : 0.00s
#     Sequence length    : 37
#     Tokens             : 429
#     Token throughput   : 51.29 tokens/s
#
#   ROLLING PERFORMANCE
#     Mean batch         : 6.260s
#     Median batch       : 6.058s
#     P95 batch          : 8.364s
#     Max batch          : 8.380s
#     Slow batches       : 5
#     Current anomaly    : NO
#
#   MEMORY / STORAGE
#     RAM available      : 2.28 GiB
#     Process RSS        : 1.6320266723632812
#     Peak RSS           : 1.67 GiB
#     Minimum RAM        : 0.64 GiB
#     External free      : 1773.40 GiB
#     Successful batches : 89
#     Debug batch output : OFF
# ────────────────────────────────────────────────────────────────────────────────────────
# [runtime] periodic runtime telemetry
#
# ────────────────────────────────────────────────────────────────────────────────────────
# RUNTIME / SPEED TELEMETRY :: sst2
# ────────────────────────────────────────────────────────────────────────────────────────
#   Progress             : 38,496/69,676 (55.25%)
#   Newly computed       : 2,912
#   Wall time            : 14m 08.2s
#   Throughput           : 3.43 samples/s
#   ETA                  : 2h 31m 22.0s
#   Current stage        : measurement
#
#   LAST BATCH
#     Range              : 38464:38496
#     New samples        : 32
#     Total              : 9.91s
#     Forward            : 9.56s
#     Tokenization       : 0.02s
#     Input transfer     : 0.00s
#     Pooling            : 0.05s
#     Conversion         : 0.00s
#     Memmap write       : 0.13s
#     Flush              : 0.00s
#     Sequence length    : 45
#     Tokens             : 477
#     Token throughput   : 48.13 tokens/s
#
#   ROLLING PERFORMANCE
#     Mean batch         : 6.575s
#     Median batch       : 6.181s
#     P95 batch          : 8.533s
#     Max batch          : 9.910s
#     Slow batches       : 5
#     Current anomaly    : NO
#
#   MEMORY / STORAGE
#     RAM available      : 2.20 GiB
#     Process RSS        : 1.6096343994140625
#     Peak RSS           : 1.67 GiB
#     Minimum RAM        : 0.64 GiB
#     External free      : 1773.40 GiB
#     Successful batches : 91
#     Debug batch output : OFF
# ────────────────────────────────────────────────────────────────────────────────────────
# [runtime] periodic runtime telemetry
#
# ────────────────────────────────────────────────────────────────────────────────────────
# RUNTIME / SPEED TELEMETRY :: sst2
# ────────────────────────────────────────────────────────────────────────────────────────
#   Progress             : 38,592/69,676 (55.39%)
#   Newly computed       : 3,008
#   Wall time            : 14m 29.2s
#   Throughput           : 3.46 samples/s
#   ETA                  : 2h 29m 41.8s
#   Current stage        : measurement
#
#   LAST BATCH
#     Range              : 38560:38592
#     New samples        : 32
#     Total              : 7.25s
#     Forward            : 6.96s
#     Tokenization       : 0.01s
#     Input transfer     : 0.00s
#     Pooling            : 0.04s
#     Conversion         : 0.00s
#     Memmap write       : 0.10s
#     Flush              : 0.00s
#     Sequence length    : 43
#     Tokens             : 340
#     Token throughput   : 46.90 tokens/s
#
#   ROLLING PERFORMANCE
#     Mean batch         : 6.875s
#     Median batch       : 6.491s
#     P95 batch          : 8.533s
#     Max batch          : 9.910s
#     Slow batches       : 5
#     Current anomaly    : NO
#
#   MEMORY / STORAGE
#     RAM available      : 2.18 GiB
#     Process RSS        : 1.6314468383789062
#     Peak RSS           : 1.67 GiB
#     Minimum RAM        : 0.64 GiB
#     External free      : 1773.40 GiB
#     Successful batches : 94
#     Debug batch output : OFF
# ────────────────────────────────────────────────────────────────────────────────────────
# [runtime] periodic runtime telemetry
#
# ────────────────────────────────────────────────────────────────────────────────────────
# RUNTIME / SPEED TELEMETRY :: sst2
# ────────────────────────────────────────────────────────────────────────────────────────
#   Progress             : 38,688/69,676 (55.53%)
#   Newly computed       : 3,104
#   Wall time            : 14m 45.6s
#   Throughput           : 3.51 samples/s
#   ETA                  : 2h 27m 21.0s
#   Current stage        : measurement
#
#   LAST BATCH
#     Range              : 38656:38688
#     New samples        : 32
#     Total              : 5.79s
#     Forward            : 5.43s
#     Tokenization       : 0.01s
#     Input transfer     : 0.00s
#     Pooling            : 0.03s
#     Conversion         : 0.00s
#     Memmap write       : 0.22s
#     Flush              : 0.00s
#     Sequence length    : 36
#     Tokens             : 279
#     Token throughput   : 48.20 tokens/s
#
#   ROLLING PERFORMANCE
#     Mean batch         : 6.732s
#     Median batch       : 6.181s
#     P95 batch          : 8.533s
#     Max batch          : 9.910s
#     Slow batches       : 5
#     Current anomaly    : NO
#
#   MEMORY / STORAGE
#     RAM available      : 2.21 GiB
#     Process RSS        : 1.6262054443359375
#     Peak RSS           : 1.67 GiB
#     Minimum RAM        : 0.64 GiB
#     External free      : 1773.40 GiB
#     Successful batches : 97
#     Debug batch output : OFF
# ────────────────────────────────────────────────────────────────────────────────────────
# [runtime] periodic runtime telemetry
#
# ────────────────────────────────────────────────────────────────────────────────────────
# RUNTIME / SPEED TELEMETRY :: sst2
# ────────────────────────────────────────────────────────────────────────────────────────
#   Progress             : 38,752/69,676 (55.62%)
#   Newly computed       : 3,168
#   Wall time            : 15m 03.5s
#   Throughput           : 3.51 samples/s
#   ETA                  : 2h 26m 59.1s
#   Current stage        : measurement
#
#   LAST BATCH
#     Range              : 38720:38752
#     New samples        : 32
#     Total              : 6.14s
#     Forward            : 5.77s
#     Tokenization       : 0.01s
#     Input transfer     : 0.00s
#     Pooling            : 0.03s
#     Conversion         : 0.00s
#     Memmap write       : 0.23s
#     Flush              : 0.00s
#     Sequence length    : 31
#     Tokens             : 312
#     Token throughput   : 50.78 tokens/s
#
#   ROLLING PERFORMANCE
#     Mean batch         : 7.019s
#     Median batch       : 6.385s
#     P95 batch          : 9.910s
#     Max batch          : 11.710s
#     Slow batches       : 5
#     Current anomaly    : NO
#
#   MEMORY / STORAGE
#     RAM available      : 2.49 GiB
#     Process RSS        : 1.6152305603027344
#     Peak RSS           : 1.67 GiB
#     Minimum RAM        : 0.64 GiB
#     External free      : 1773.40 GiB
#     Successful batches : 99
#     Debug batch output : OFF
# ────────────────────────────────────────────────────────────────────────────────────────
# [runtime] periodic runtime telemetry
#
# ────────────────────────────────────────────────────────────────────────────────────────
# RUNTIME / SPEED TELEMETRY :: sst2
# ────────────────────────────────────────────────────────────────────────────────────────
#   Progress             : 38,848/69,676 (55.76%)
#   Newly computed       : 3,264
#   Wall time            : 15m 20.3s
#   Throughput           : 3.55 samples/s
#   ETA                  : 2h 24m 52.3s
#   Current stage        : measurement
#
#   LAST BATCH
#     Range              : 38816:38848
#     New samples        : 32
#     Total              : 7.93s
#     Forward            : 7.55s
#     Tokenization       : 0.02s
#     Input transfer     : 0.00s
#     Pooling            : 0.04s
#     Conversion         : 0.00s
#     Memmap write       : 0.19s
#     Flush              : 0.00s
#     Sequence length    : 53
#     Tokens             : 403
#     Token throughput   : 50.83 tokens/s
#
#   ROLLING PERFORMANCE
#     Mean batch         : 6.840s
#     Median batch       : 6.023s
#     P95 batch          : 9.910s
#     Max batch          : 11.710s
#     Slow batches       : 5
#     Current anomaly    : NO
#
#   MEMORY / STORAGE
#     RAM available      : 2.36 GiB
#     Process RSS        : 1.6865882873535156
#     Peak RSS           : 1.69 GiB
#     Minimum RAM        : 0.64 GiB
#     External free      : 1773.40 GiB
#     Successful batches : 102
#     Debug batch output : OFF
# ────────────────────────────────────────────────────────────────────────────────────────
# [runtime] periodic runtime telemetry
#
# ────────────────────────────────────────────────────────────────────────────────────────
# RUNTIME / SPEED TELEMETRY :: sst2
# ────────────────────────────────────────────────────────────────────────────────────────
#   Progress             : 38,912/69,676 (55.85%)
#   Newly computed       : 3,328
#   Wall time            : 15m 37.0s
#   Throughput           : 3.55 samples/s
#   ETA                  : 2h 24m 21.4s
#   Current stage        : measurement
#
#   LAST BATCH
#     Range              : 38880:38912
#     New samples        : 32
#     Total              : 9.85s
#     Forward            : 9.28s
#     Tokenization       : 0.01s
#     Input transfer     : 0.00s
#     Pooling            : 0.05s
#     Conversion         : 0.00s
#     Memmap write       : 0.23s
#     Flush              : 0.10s
#     Sequence length    : 50
#     Tokens             : 439
#     Token throughput   : 44.57 tokens/s
#
#   ROLLING PERFORMANCE
#     Mean batch         : 7.082s
#     Median batch       : 7.020s
#     P95 batch          : 9.910s
#     Max batch          : 11.710s
#     Slow batches       : 5
#     Current anomaly    : NO
#
#   MEMORY / STORAGE
#     RAM available      : 2.44 GiB
#     Process RSS        : 1.6256179809570312
#     Peak RSS           : 1.69 GiB
#     Minimum RAM        : 0.64 GiB
#     External free      : 1773.40 GiB
#     Successful batches : 104
#     Debug batch output : OFF
# ────────────────────────────────────────────────────────────────────────────────────────
# [runtime] periodic runtime telemetry
#
# ────────────────────────────────────────────────────────────────────────────────────────
# RUNTIME / SPEED TELEMETRY :: sst2
# ────────────────────────────────────────────────────────────────────────────────────────
#   Progress             : 39,008/69,676 (55.98%)
#   Newly computed       : 3,424
#   Wall time            : 15m 58.7s
#   Throughput           : 3.57 samples/s
#   ETA                  : 2h 23m 06.7s
#   Current stage        : measurement
#
#   LAST BATCH
#     Range              : 38976:39008
#     New samples        : 32
#     Total              : 6.79s
#     Forward            : 6.40s
#     Tokenization       : 0.01s
#     Input transfer     : 0.00s
#     Pooling            : 0.04s
#     Conversion         : 0.00s
#     Memmap write       : 0.23s
#     Flush              : 0.00s
#     Sequence length    : 38
#     Tokens             : 337
#     Token throughput   : 49.63 tokens/s
#
#   ROLLING PERFORMANCE
#     Mean batch         : 7.275s
#     Median batch       : 7.020s
#     P95 batch          : 9.910s
#     Max batch          : 11.710s
#     Slow batches       : 5
#     Current anomaly    : NO
#
#   MEMORY / STORAGE
#     RAM available      : 2.33 GiB
#     Process RSS        : 1.6608009338378906
#     Peak RSS           : 1.69 GiB
#     Minimum RAM        : 0.64 GiB
#     External free      : 1773.40 GiB
#     Successful batches : 107
#     Debug batch output : OFF
# ────────────────────────────────────────────────────────────────────────────────────────
# [runtime] periodic runtime telemetry
#
# ────────────────────────────────────────────────────────────────────────────────────────
# RUNTIME / SPEED TELEMETRY :: sst2
# ────────────────────────────────────────────────────────────────────────────────────────
#   Progress             : 39,104/69,676 (56.12%)
#   Newly computed       : 3,520
#   Wall time            : 16m 17.6s
#   Throughput           : 3.60 samples/s
#   ETA                  : 2h 21m 30.6s
#   Current stage        : measurement
#
#   LAST BATCH
#     Range              : 39072:39104
#     New samples        : 32
#     Total              : 5.87s
#     Forward            : 5.43s
#     Tokenization       : 0.01s
#     Input transfer     : 0.00s
#     Pooling            : 0.04s
#     Conversion         : 0.00s
#     Memmap write       : 0.27s
#     Flush              : 0.00s
#     Sequence length    : 34
#     Tokens             : 416
#     Token throughput   : 70.85 tokens/s
#
#   ROLLING PERFORMANCE
#     Mean batch         : 6.955s
#     Median batch       : 6.467s
#     P95 batch          : 9.910s
#     Max batch          : 11.710s
#     Slow batches       : 5
#     Current anomaly    : NO
#
#   MEMORY / STORAGE
#     RAM available      : 2.24 GiB
#     Process RSS        : 1.6585044860839844
#     Peak RSS           : 1.69 GiB
#     Minimum RAM        : 0.64 GiB
#     External free      : 1773.40 GiB
#     Successful batches : 110
#     Debug batch output : OFF
# ────────────────────────────────────────────────────────────────────────────────────────
# [runtime] periodic runtime telemetry
#
# ────────────────────────────────────────────────────────────────────────────────────────
# RUNTIME / SPEED TELEMETRY :: sst2
# ────────────────────────────────────────────────────────────────────────────────────────
#   Progress             : 39,200/69,676 (56.26%)
#   Newly computed       : 3,616
#   Wall time            : 16m 37.3s
#   Throughput           : 3.63 samples/s
#   ETA                  : 2h 20m 05.6s
#   Current stage        : measurement
#
#   LAST BATCH
#     Range              : 39168:39200
#     New samples        : 32
#     Total              : 5.88s
#     Forward            : 5.54s
#     Tokenization       : 0.01s
#     Input transfer     : 0.00s
#     Pooling            : 0.03s
#     Conversion         : 0.00s
#     Memmap write       : 0.22s
#     Flush              : 0.00s
#     Sequence length    : 35
#     Tokens             : 316
#     Token throughput   : 53.70 tokens/s
#
#   ROLLING PERFORMANCE
#     Mean batch         : 6.762s
#     Median batch       : 6.116s
#     P95 batch          : 9.850s
#     Max batch          : 11.710s
#     Slow batches       : 5
#     Current anomaly    : NO
#
#   MEMORY / STORAGE
#     RAM available      : 2.14 GiB
#     Process RSS        : 1.6709098815917969
#     Peak RSS           : 1.69 GiB
#     Minimum RAM        : 0.64 GiB
#     External free      : 1773.40 GiB
#     Successful batches : 113
#     Debug batch output : OFF
# ────────────────────────────────────────────────────────────────────────────────────────
# [runtime] periodic runtime telemetry
#
# ────────────────────────────────────────────────────────────────────────────────────────
# RUNTIME / SPEED TELEMETRY :: sst2
# ────────────────────────────────────────────────────────────────────────────────────────
#   Progress             : 39,296/69,676 (56.40%)
#   Newly computed       : 3,712
#   Wall time            : 16m 53.5s
#   Throughput           : 3.66 samples/s
#   ETA                  : 2h 18m 14.7s
#   Current stage        : measurement
#
#   LAST BATCH
#     Range              : 39264:39296
#     New samples        : 32
#     Total              : 6.16s
#     Forward            : 5.79s
#     Tokenization       : 0.01s
#     Input transfer     : 0.00s
#     Pooling            : 0.06s
#     Conversion         : 0.00s
#     Memmap write       : 0.19s
#     Flush              : 0.00s
#     Sequence length    : 34
#     Tokens             : 317
#     Token throughput   : 51.45 tokens/s
#
#   ROLLING PERFORMANCE
#     Mean batch         : 6.676s
#     Median batch       : 6.116s
#     P95 batch          : 9.850s
#     Max batch          : 11.710s
#     Slow batches       : 5
#     Current anomaly    : NO
#
#   MEMORY / STORAGE
#     RAM available      : 2.01 GiB
#     Process RSS        : 1.676483154296875
#     Peak RSS           : 1.69 GiB
#     Minimum RAM        : 0.64 GiB
#     External free      : 1773.40 GiB
#     Successful batches : 116
#     Debug batch output : OFF
# ────────────────────────────────────────────────────────────────────────────────────────
# [runtime] periodic runtime telemetry

# %%
""" Main run of the models - full datasets. 
# =============================================================================
# CELL 3 — RUN MODEL MATRIX ON CLEAN DATA
# =============================================================================

# The pipeline writes to a single fixed root:
#     /Volumes/Amirali/Probing-Emotions/
# `base_output` and `auto_batch_size` no longer exist as arguments.
# Ordering is controlled by /Volumes/Amirali/Probing-Emotions/extraction_order.json.

NEW_EXPERIMENT_ID = "master_v1"

results = EX.run_model_matrix(
    datasets=DATASETS,
    dataset_csv_hashes=CSV_HASHES,
    groups=None,
    experiment_id=NEW_EXPERIMENT_ID,
    pooling="mean",
    max_length=512,
    use_half_precision=True,
    flush_every_batches=8,
    continue_on_model_error=True,
    show_verbose=True,
    show_info=True,
    show_critical=True,
    show_debug=True,
)

print(f"Result records : {len(results)}")
print(f"Output root    : {EX.EXTERNAL_ROOT}")
print(f"HF cache       : {EX.HF_HUB_CACHE}")
"""

# %% [markdown]
# ### How to load the missing QWENs ?

# %%
# =============================================================================
# CELL 4 — SUMMARY FROM RUNS/CLEAN_V1
# =============================================================================
EXTERNAL_ROOT = "/Volumes/Amirali/Probing-Emotions"
RUN_ROOT = EXTERNAL_ROOT / "runs" / NEW_EXPERIMENT_ID
df_results = load_experiment_results(RUN_ROOT)

if not df_results.empty:
    display_title("Extraction progress")
    df_show = df_results.copy()
    df_show["model"] = df_show["model"].str.replace("__", "/", regex=False)
    display(df_show[["model", "dataset", "status", "completed_samples", "total_samples"]])
    display_info(f"Pairs discovered: <b>{len(df_results)}</b>")
else:
    display_info("No extraction metadata yet — run CELL 3.")

# %%
from sys import audit


df_audit = pd.DataFrame(audit)
if not df_audit.empty:
    # Primary contract: extraction's n_samples must equal the processed CSV's
    # row count. Otherwise the memmap is misaligned with the source data.
    def _csv_len(dataset_name):
        return len(DATASETS.get(dataset_name, []))
    df_audit["csv_rows"] = df_audit["dataset_name"].map(_csv_len)
    df_audit["csv_matches"] = df_audit["n_samples"] == df_audit["csv_rows"]
    df_audit["row_count_ok"] = df_audit["n_samples"] == df_audit["completed_count"]

    display(df_audit[[
        "model_name", "dataset_name", "n_samples", "csv_rows", "completed_count",
        "csv_matches", "row_count_ok",
        "status", "checksum_match", "sample_ids_match",
    ]])

# %%
# =============================================================================
# CELL 5 – VISUALISATIONS & ANALYSIS 
# =============================================================================

if not df_results.empty:
    # Prepare data for plotting
    df = df_results.copy()
    df['completion_pct'] = df['completed_samples'] / df['total_samples'] * 100
    df['status_clean'] = df['status'].replace({'complete': 'Complete', 'partial': 'Partial', 'failed': 'Failed', 'already_complete': 'Already Complete'})

    sns.set_style("darkgrid")
    plt.rcParams.update({
        'figure.facecolor': '#1e1e1e',
        'axes.facecolor': '#2d2d2d',
        'axes.edgecolor': '#d4d4d4',
        'axes.labelcolor': '#d4d4d4',
        'text.color': '#d4d4d4',
        'xtick.color': '#d4d4d4',
        'ytick.color': '#d4d4d4',
        'grid.color': '#444444',
        'legend.facecolor': '#2d2d2d',
        'legend.edgecolor': '#d4d4d4',
    })

    # ---- 1. Completion status per model/dataset ----
    fig, ax = plt.subplots(figsize=(12, 8))
    pivot = df.pivot_table(index='model', columns='dataset', values='completion_pct', aggfunc='max')
    sns.heatmap(pivot, annot=True, fmt=".0f", cmap="viridis", cbar_kws={'label': 'Completion %'}, ax=ax)
    ax.set_title('Completion Percentage by Model and Dataset', color='#4fc3f7')
    plt.tight_layout()
    plt.show()

    # ---- 2. Throughput (samples/sec) by model ----
    df_complete = df[df['samples_per_second'].notna()]
    if not df_complete.empty:
        fig, ax = plt.subplots(figsize=(14, 6))
        sns.barplot(data=df_complete, x='model', y='samples_per_second', hue='dataset', palette='coolwarm', ax=ax)
        ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha='right')
        ax.set_title('Extraction Throughput (samples/sec)', color='#4fc3f7')
        plt.tight_layout()
        plt.show()

    # ---- 3. Total time per model ----
    df_time = df.groupby('model')['elapsed_seconds'].sum().reset_index().sort_values('elapsed_seconds', ascending=False)
    fig, ax = plt.subplots(figsize=(12, 6))
    sns.barplot(data=df_time, x='elapsed_seconds', y='model', palette='magma', ax=ax)
    ax.set_xlabel('Total Elapsed Time (seconds)')
    ax.set_title('Cumulative Extraction Time per Model', color='#4fc3f7')
    plt.tight_layout()
    plt.show()

    # ---- 4. Label coverage for completed datasets ----
    # We'll just display label column info
    display_title("Label Columns Used")
    display(df[['model', 'dataset', 'label_column']].drop_duplicates())
else:
    display_info("No data to visualise. Please run extraction first.")

# %%
# =============================================================================
# CELL 6 – FINAL SUMMARY & EXPORT
# =============================================================================

if not df_results.empty:
    # Save consolidated CSV
    output_csv = exp_root / "extraction_summary.csv"
    df_results.to_csv(output_csv, index=False)
    display_title("Final Report")
    display(df_results)
    display_info(f"Report exported to <code>{output_csv}</code>")
else:
    display_info("Nothing to export yet.")

# %%
discover_extractions(exp_root)

# %%
# Check which models have at least one dataset complete
model_status = df_results.groupby("model")["dataset"].nunique()
print(model_status)

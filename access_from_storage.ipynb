# %%
import json
import os

# Navigate to the directory (optional)
external_drive_path = '/Volumes/Amirali/hidden_states'
os.chdir(external_drive_path)  # Change working directory to the drive

# Open and read the JSON file
drive_path = 'QwenQwen2-0.5B_goEmo_654.json'  # Now relative to the drive's root
with open(drive_path, 'r') as f:
    data = json.load(f)  # Pass the file object `f`, not the path string
    
# Print the first dictionary's keys (if the list isn't empty)
if data and isinstance(data[0], dict):  # Check if the first item is a dictionary
    print("First dictionary keys:", list(data[0].keys())[:5])  # First 5 keys
else:
    print("Data is not a list of dictionaries.")

# Print the first 5 items in the list (entire dictionaries)
print("First 5 items in the list:")
print(data[:5])  # Slices the list to show the first 5 elements
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 10
#       8 # Open and read the JSON file
#       9 drive_path = 'QwenQwen2-0.5B_goEmo_654.json'  # Now relative to the drive's root
# ---> 10 with open(drive_path, 'r') as f:
#      11     data = json.load(f)  # Pass the file object `f`, not the path string
#      13 # Print the first dictionary's keys (if the list isn't empty)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/IPython/core/interactiveshell.py:324, in _modified_open(file, *args, **kwargs)
#     317 if file in {0, 1, 2}:
#     318     raise ValueError(
#     319         f"IPython won't let you open fd={file} by default "
#     320         "as it is likely to crash IPython. If you know what you are doing, "
#     321         "you can use builtins' open."
#     322     )
# ...

# %%
# =============================================================================
# CELL 1 – IMPORTS, DARK THEME, AND HELPERS
# =============================================================================

import importlib
import sys
import json
from pathlib import Path
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from IPython.display import display, HTML, Markdown

# -------------------- Dark Theme --------------------
display(HTML("""
<style>
    body, .jp-Notebook, .jp-OutputArea-output, .jp-RenderedHTMLCommon {
        background-color: #1e1e1e !important;
        color: #d4d4d4 !important;
    }
    h2, h3, h4 {
        color: #4fc3f7 !important;
        border-bottom: 2px solid #3498db !important;
        padding-bottom: 4px;
    }
    b, strong { color: #f48fb1 !important; }
    .highlight {
        background-color: #2d2d2d !important;
        padding: 10px;
        border-left: 4px solid #3498db;
        margin: 4px 0;
        color: #d4d4d4;
    }
    code {
        background-color: #333 !important;
        color: #ffcc80 !important;
        padding: 2px 4px;
        border-radius: 4px;
    }
    .dataframe {
        background-color: #2d2d2d !important;
        color: #d4d4d4 !important;
    }
</style>
"""))

# -------------------- Verbosity Flags --------------------
SHOW_VERBOSE = False
SHOW_INFO = True
SHOW_CRITICAL = True
SHOW_DEBUG = True
# For demonstration, we keep them False to reduce output; you can set True as needed.


# -------------------- Import Extraction Module --------------------
import Extraction as Extraction6
importlib.reload(Extraction6)

# -------------------- Helper Functions --------------------
def display_title(title: str):
    display(HTML(f"<h2>{title}</h2>"))

def display_info(message: str):
    display(HTML(f"<div class='highlight'>{message}</div>"))
    

def discover_extractions(exp_root: Path) -> pd.DataFrame:
    rows = []
    for f in exp_root.rglob("extraction.json"):
        parts = f.relative_to(exp_root).parts
        try:
            models_idx = parts.index("models")
            datasets_idx = parts.index("datasets")
            model = "/".join(parts[models_idx+1:datasets_idx])
            dataset = parts[datasets_idx+1]
            rows.append({"model": model, "dataset": dataset, "path": str(f)})
        except ValueError:
            rows.append({"model": None, "dataset": None, "path": str(f)})
    return pd.DataFrame(rows)

def load_experiment_results(exp_root: Path) -> pd.DataFrame:
    """
    Load all extraction results from the experiment directory, inferring model and
    dataset names from the file path if they are missing in the JSON.
    """
    records = []
    exp_root = Path(exp_root)
    if not exp_root.exists():
        return pd.DataFrame()

    for meta_file in exp_root.rglob("extraction.json"):
        try:
            with open(meta_file, "r") as f:
                meta = json.load(f)

            # Extract model and dataset from path (most reliable)
            parts = meta_file.relative_to(exp_root).parts
            try:
                models_idx = parts.index("models")
                datasets_idx = parts.index("datasets")
                model = "/".join(parts[models_idx+1:datasets_idx])
                dataset = parts[datasets_idx+1]
            except ValueError:
                # Fallback to metadata
                model = meta.get("model", {}).get("name")
                dataset = meta.get("dataset", {}).get("name")

            record = {
                "experiment_id": meta.get("experiment_id"),
                "model": model,
                "dataset": dataset,
                "status": meta.get("status"),
                "completed_samples": meta.get("performance", {}).get("completed_samples"),
                "total_samples": meta.get("dataset", {}).get("samples"),
                "batch_size": meta.get("extraction", {}).get("batch_size"),
                "pooling": meta.get("extraction", {}).get("pooling"),
                "max_length": meta.get("extraction", {}).get("max_length"),
                "samples_per_second": meta.get("performance", {}).get("samples_per_second"),
                "tokens_per_second": meta.get("performance", {}).get("tokens_per_second"),
                "elapsed_seconds": meta.get("performance", {}).get("elapsed_seconds"),
                "error": None,
                "text_column": meta.get("dataset", {}).get("text_column"),
                "label_column": meta.get("dataset", {}).get("labels", {}).get("label_column"),
            }
            records.append(record)
        except Exception:
            continue

    return pd.DataFrame(records)

print("Environment ready. Dark theme applied.")
# Out:
# <style>
#     body, .jp-Notebook, .jp-OutputArea-output, .jp-RenderedHTMLCommon {
#         background-color: #1e1e1e !important;
#         color: #d4d4d4 !important;
#     }
#     h2, h3, h4 {
#         color: #4fc3f7 !important;
#         border-bottom: 2px solid #3498db !important;
#         padding-bottom: 4px;
#     }
#     b, strong { color: #f48fb1 !important; }
#     .highlight {
#         background-color: #2d2d2d !important;
#         padding: 10px;
#         border-left: 4px solid #3498db;
#         margin: 4px 0;
#         color: #d4d4d4;
#     }
#     code {
#         background-color: #333 !important;
#         color: #ffcc80 !important;
#         padding: 2px 4px;
#         border-radius: 4px;
#     }
#     .dataframe {
#         background-color: #2d2d2d !important;
#         color: #d4d4d4 !important;
#     }
# </style>
# Environment ready. Dark theme applied.

# %%
# =============================================================================
# CELL 2 – LOAD AND INSPECT DATASETS
# =============================================================================

from Get_Go_Emo import get_go
from Get_Isear import get_isr

goEmo = get_go()
isear = get_isr()

DATASETS = {
    "goEmo": goEmo,
    "ISEAR": isear,
}

for name, df in DATASETS.items():
    display_title(f"Dataset: {name}")
    display_info(f"Shape: {df.shape}")
    display(df.head(2))
    text_col = Extraction6.detect_text_column(df, show_verbose=False)
    label_cols = [c for c in df.columns if c.lower() in ("labels", "label", "emotion", "target")]
    label_col = label_cols[0] if label_cols else None
    display_info(f"Text column: <b>{text_col}</b><br>Label column: <b>{label_col or 'None'}</b><br>Samples: <b>{len(df):,}</b>")

display_title("Unified ID Scheme")
display_info("""
Each sample is assigned a unique integer ID (0..N-1) matching its row index.
This ID links:
• Input text (original DataFrame index)
• Hidden state vector (row in hidden_states.npy)
• Label (row in labels.npy)
No shuffling occurs, guaranteeing one‑to‑one mapping.
""")
# Out:
# <h2>Dataset: goEmo</h2>
# <div class='highlight'>Shape: (54263, 2)</div>
#   labels                                         clean_text
# 0   [27]  my favourite food is anything i didnt have to ...
# 1   [27]  now if he does off himself, everyone will thin...
# <div class='highlight'>Text column: <b>clean_text</b><br>Label column: <b>labels</b><br>Samples: <b>54,263</b></div>
# <h2>Dataset: ISEAR</h2>
# <div class='highlight'>Shape: (7666, 2)</div>
#                                           clean_text  labels
# 0  during the period of falling in love each time...       1
# 1          when i was involved in a traffic accident       2
# <div class='highlight'>Text column: <b>clean_text</b><br>Label column: <b>labels</b><br>Samples: <b>7,666</b></div>
# <h2>Unified ID Scheme</h2>
# <div class='highlight'>
# Each sample is assigned a unique integer ID (0..N-1) matching its row index.
# This ID links:
# • Input text (original DataFrame index)
# • Hidden state vector (row in hidden_states.npy)
# • Label (row in labels.npy)
# No shuffling occurs, guaranteeing one‑to‑one mapping.
# </div>

# %%
# =============================================================================
# CELL 3 – RUN MODEL MATRIX (ENHANCED, WITH SAFEGUARDS)
# =============================================================================

# This call will automatically resume from existing completions.
# If interrupted, simply re-run this cell to continue.
results = Extraction6.run_model_matrix(
    datasets=DATASETS,
    groups=None,                     # all 25 models
    base_output="/Volumes/Amirali/hidden_states",
    pooling="mean",
    max_length=512,
    use_half_precision=True,
    auto_batch_size=False,
    flush_every_batches=8,
    continue_on_model_error=True,
    show_verbose=SHOW_VERBOSE,
    show_info=SHOW_INFO,
    show_critical=SHOW_CRITICAL,
    show_debug=SHOW_DEBUG,
)

print(f"Returned result records: {len(results)}")
# Out:
# ╔══════════════════════════════════════════════════════════════════════════════════════╗
# ║ MODEL MATRIX                                                                         ║
# ╚══════════════════════════════════════════════════════════════════════════════════════╝
#   Requested experiment : baseline_v5_001
#   Transformers         : 4.47.1
#   PyTorch              : 2.2.2
#   Models               : 25
#   Datasets             : 2
#   Runtime batch tuning : DISABLED
#   Output root          : /Volumes/Amirali/hidden_states
# 01. [01_encoders] BERT         0.11B  google-bert/bert-base-uncased
# 02. [01_encoders] DistilBERT   0.066B  distilbert/distilbert-base-uncased
# 03. [01_encoders] RoBERTa      0.125B  FacebookAI/roberta-base
# 04. [01_encoders] ELECTRA      0.014B  google/electra-small-discriminator
# 05. [01_encoders] DeBERTa      0.14B  microsoft/deberta-v3-small
# 06. [02_early_decoders] GPT          0.124B  gpt2
# 07. [02_early_decoders] GPT-Neo      0.125B  EleutherAI/gpt-neo-125m
# 08. [02_early_decoders] OPT          0.125B  facebook/opt-125m
# 09. [03_tiny_modern] SmolLM2      0.135B  HuggingFaceTB/SmolLM2-135M
# 10. [03_tiny_modern] SmolLM2      0.36B  HuggingFaceTB/SmolLM2-360M
# 11. [03_tiny_modern] Gemma        0.27B  google/gemma-3-270m
# 12. [03_tiny_modern] Qwen         0.5B  Qwen/Qwen2-0.5B
# 13. [03_tiny_modern] Qwen         0.5B  Qwen/Qwen2.5-0.5B
# 14. [03_tiny_modern] Qwen         0.6B  Qwen/Qwen3-0.6B-Base
# 15. [04_qwen_scaling] Qwen         1.5B  Qwen/Qwen2-1.5B
# 16. [04_qwen_scaling] Qwen         1.54B  Qwen/Qwen2.5-1.5B
# 17. [04_qwen_scaling] Qwen         3.09B  Qwen/Qwen2.5-3B
# 18. [04_qwen_scaling] Qwen         1.7B  Qwen/Qwen3-1.7B-Base
# 19. [05_independent_small] SmolLM2      1.7B  HuggingFaceTB/SmolLM2-1.7B
# 20. [05_independent_small] TinyLlama    1.1B  TinyLlama/TinyLlama-1.1B-intermediate-step-1431k-3T
# 21. [05_independent_small] Gemma        1B  google/gemma-3-1b-pt
# 22. [05_independent_small] Llama        1B  meta-llama/Llama-3.2-1B
# 23. [06_stretch] Qwen         4B  Qwen/Qwen3-4B-Base
# 24. [06_stretch] Llama        3B  meta-llama/Llama-3.2-3B
# 25. [06_stretch] Gemma        4B  google/gemma-3-4b-pt
#
# ↻ EXISTING EXPERIMENT DETECTED
#   Experiment ID        : baseline_v5_001
#   Saved hyperparameter : d90449246241487f
#   Manifest             : /Volumes/Amirali/hidden_states/experiments/baseline_v5_001/run_manifest.json
#   The saved experiment configuration is authoritative.
#   Current-call overrides are ignored for this resume.
#   Requested overrides  : {'pooling': 'mean', 'max_length': 512, 'use_half_precision': True, 'flush_every_batches': 8}
#
#
# ╔══════════════════════════════════════════════════════════════════════════════════════╗
# ║ HIDDEN STATE EXTRACTION EXPERIMENT                                                   ║
# ╚══════════════════════════════════════════════════════════════════════════════════════╝
#   Experiment ID       : baseline_v5_001
#   Hyperparameter hash : d90449246241487f
#   Device              : cpu
#   Models requested    : 25
#   Datasets            : 2
#   Pooling             : mean
#   Max sequence length : 512
#   Runtime batch tuning: DISABLED
#   Existing experiment : YES
#   Output root         : /Volumes/Amirali/hidden_states/experiments/baseline_v5_001
#   Transformers        : 4.47.1
#   PyTorch             : 2.2.2
#
# ╔══════════════════════════════════════════════════════════════════════════════════════╗
# ║ MODEL 1/25 :: google-bert/bert-base-uncased                                          ║
# ╚══════════════════════════════════════════════════════════════════════════════════════╝
#   Family              : BERT
#   Generation          : 2018
#   Parameters          : 0.11B
#   Architecture        : encoder
#   Training status     : pretrained
#   FROZEN batch        : 64
#   Gated               : False
#   Repaired goEmo: labels.npy already compatible, updated extraction.json with v2 fields
#   Updated metadata for goEmo
#   Repaired ISEAR: labels.npy already compatible, updated extraction.json with v2 fields
#   Updated metadata for ISEAR
# ✓ SKIPPED — all datasets already complete.
#
# ╔══════════════════════════════════════════════════════════════════════════════════════╗
# ║ MODEL 2/25 :: distilbert/distilbert-base-uncased                                     ║
# ╚══════════════════════════════════════════════════════════════════════════════════════╝
#   Family              : DistilBERT
#   Generation          : 2019
#   Parameters          : 0.066B
#   Architecture        : encoder
#   Training status     : pretrained_distilled
#   FROZEN batch        : 64
#   Gated               : False
#   Repaired goEmo: labels.npy already compatible, updated extraction.json with v2 fields
#   Updated metadata for goEmo
#   Repaired ISEAR: labels.npy already compatible, updated extraction.json with v2 fields
#   Updated metadata for ISEAR
# ✓ SKIPPED — all datasets already complete.
#
# ╔══════════════════════════════════════════════════════════════════════════════════════╗
# ║ MODEL 3/25 :: FacebookAI/roberta-base                                                ║
# ╚══════════════════════════════════════════════════════════════════════════════════════╝
#   Family              : RoBERTa
#   Generation          : 2019
#   Parameters          : 0.125B
#   Architecture        : encoder
#   Training status     : pretrained
#   FROZEN batch        : 64
#   Gated               : False
#   Repaired goEmo: labels.npy already compatible, updated extraction.json with v2 fields
#   Updated metadata for goEmo
#   Repaired ISEAR: labels.npy already compatible, updated extraction.json with v2 fields
#   Updated metadata for ISEAR
# ✓ SKIPPED — all datasets already complete.
#
# ╔══════════════════════════════════════════════════════════════════════════════════════╗
# ║ MODEL 4/25 :: google/electra-small-discriminator                                     ║
# ╚══════════════════════════════════════════════════════════════════════════════════════╝
#   Family              : ELECTRA
#   Generation          : 2020
#   Parameters          : 0.014B
#   Architecture        : encoder
#   Training status     : pretrained_discriminator
#   FROZEN batch        : 64
#   Gated               : False
#   Repaired goEmo: labels.npy already compatible, updated extraction.json with v2 fields
#   Updated metadata for goEmo
#   Repaired ISEAR: labels.npy already compatible, updated extraction.json with v2 fields
#   Updated metadata for ISEAR
# ✓ SKIPPED — all datasets already complete.
#
# ╔══════════════════════════════════════════════════════════════════════════════════════╗
# ║ MODEL 5/25 :: microsoft/deberta-v3-small                                             ║
# ╚══════════════════════════════════════════════════════════════════════════════════════╝
#   Family              : DeBERTa
#   Generation          : 2021
#   Parameters          : 0.14B
#   Architecture        : encoder
#   Training status     : pretrained
#   FROZEN batch        : 64
#   Gated               : False
#   Repaired goEmo: labels.npy already compatible, updated extraction.json with v2 fields
#   Updated metadata for goEmo
#   Repaired ISEAR: labels.npy already compatible, updated extraction.json with v2 fields
#   Updated metadata for ISEAR
# ✓ SKIPPED — all datasets already complete.
#
# ╔══════════════════════════════════════════════════════════════════════════════════════╗
# ║ MODEL 6/25 :: gpt2                                                                   ║
# ╚══════════════════════════════════════════════════════════════════════════════════════╝
#   Family              : GPT
#   Generation          : 2019
#   Parameters          : 0.124B
#   Architecture        : decoder
#   Training status     : pretrained
#   FROZEN batch        : 64
#   Gated               : False
#   Repaired goEmo: labels.npy already compatible, updated extraction.json with v2 fields
#   Updated metadata for goEmo
#   Repaired ISEAR: labels.npy already compatible, updated extraction.json with v2 fields
#   Updated metadata for ISEAR
# ✓ SKIPPED — all datasets already complete.
#
# ╔══════════════════════════════════════════════════════════════════════════════════════╗
# ║ MODEL 7/25 :: EleutherAI/gpt-neo-125m                                                ║
# ╚══════════════════════════════════════════════════════════════════════════════════════╝
#   Family              : GPT-Neo
#   Generation          : 2021
#   Parameters          : 0.125B
#   Architecture        : decoder
#   Training status     : pretrained
#   FROZEN batch        : 64
#   Gated               : False
#   Repaired goEmo: labels.npy already compatible, updated extraction.json with v2 fields
#   Updated metadata for goEmo
#   Repaired ISEAR: labels.npy already compatible, updated extraction.json with v2 fields
#   Updated metadata for ISEAR
# ✓ SKIPPED — all datasets already complete.
#
# ╔══════════════════════════════════════════════════════════════════════════════════════╗
# ║ MODEL 8/25 :: facebook/opt-125m                                                      ║
# ╚══════════════════════════════════════════════════════════════════════════════════════╝
#   Family              : OPT
#   Generation          : 2022
#   Parameters          : 0.125B
#   Architecture        : decoder
#   Training status     : pretrained
#   FROZEN batch        : 64
#   Gated               : False
#   Repaired goEmo: labels.npy already compatible, updated extraction.json with v2 fields
#   Updated metadata for goEmo
#   Repaired ISEAR: labels.npy already compatible, updated extraction.json with v2 fields
#   Updated metadata for ISEAR
# ✓ SKIPPED — all datasets already complete.
#
# ╔══════════════════════════════════════════════════════════════════════════════════════╗
# ║ MODEL 9/25 :: HuggingFaceTB/SmolLM2-135M                                             ║
# ╚══════════════════════════════════════════════════════════════════════════════════════╝
#   Family              : SmolLM2
#   Generation          : 2024
#   Parameters          : 0.135B
#   Architecture        : decoder
#   Training status     : pretrained
#   FROZEN batch        : 64
#   Gated               : False
#   Repaired goEmo: labels.npy already compatible, updated extraction.json with v2 fields
#   Updated metadata for goEmo
#   Repaired ISEAR: labels.npy already compatible, updated extraction.json with v2 fields
#   Updated metadata for ISEAR
# ✓ SKIPPED — all datasets already complete.
#
# ╔══════════════════════════════════════════════════════════════════════════════════════╗
# ║ MODEL 10/25 :: HuggingFaceTB/SmolLM2-360M                                            ║
# ╚══════════════════════════════════════════════════════════════════════════════════════╝
#   Family              : SmolLM2
#   Generation          : 2024
#   Parameters          : 0.36B
#   Architecture        : decoder
#   Training status     : pretrained
#   FROZEN batch        : 32
#   Gated               : False
#   Repaired goEmo: labels.npy already compatible, updated extraction.json with v2 fields
#   Updated metadata for goEmo
#   Repaired ISEAR: labels.npy already compatible, updated extraction.json with v2 fields
#   Updated metadata for ISEAR
# ✓ SKIPPED — all datasets already complete.
#
# ╔══════════════════════════════════════════════════════════════════════════════════════╗
# ║ MODEL 11/25 :: google/gemma-3-270m                                                   ║
# ╚══════════════════════════════════════════════════════════════════════════════════════╝
#   Family              : Gemma
#   Generation          : 2025
#   Parameters          : 0.27B
#   Architecture        : decoder
#   Training status     : pretrained
#   FROZEN batch        : 32
#   Gated               : True
# ⚠ SKIPPED: requires transformers>=4.50.0; installed=4.47.1
#
# ╔══════════════════════════════════════════════════════════════════════════════════════╗
# ║ MODEL 12/25 :: Qwen/Qwen2-0.5B                                                       ║
# ╚══════════════════════════════════════════════════════════════════════════════════════╝
#   Family              : Qwen
#   Generation          : Qwen2
#   Parameters          : 0.5B
#   Architecture        : decoder
#   Training status     : pretrained_base
#   FROZEN batch        : 32
#   Gated               : False
#   Repaired goEmo: labels.npy already compatible, updated extraction.json with v2 fields
#   Updated metadata for goEmo
#   Repaired ISEAR: labels.npy already compatible, updated extraction.json with v2 fields
#   Updated metadata for ISEAR
# ✓ SKIPPED — all datasets already complete.
#
# ╔══════════════════════════════════════════════════════════════════════════════════════╗
# ║ MODEL 13/25 :: Qwen/Qwen2.5-0.5B                                                     ║
# ╚══════════════════════════════════════════════════════════════════════════════════════╝
#   Family              : Qwen
#   Generation          : Qwen2.5
#   Parameters          : 0.5B
#   Architecture        : decoder
#   Training status     : pretrained_base
#   FROZEN batch        : 32
#   Gated               : False
#   Repaired goEmo: labels.npy already compatible, updated extraction.json with v2 fields
#   Updated metadata for goEmo
#   Repaired ISEAR: labels.npy already compatible, updated extraction.json with v2 fields
#   Updated metadata for ISEAR
# ✓ SKIPPED — all datasets already complete.
#
# ╔══════════════════════════════════════════════════════════════════════════════════════╗
# ║ MODEL 14/25 :: Qwen/Qwen3-0.6B-Base                                                  ║
# ╚══════════════════════════════════════════════════════════════════════════════════════╝
#   Family              : Qwen
#   Generation          : Qwen3
#   Parameters          : 0.6B
#   Architecture        : decoder
#   Training status     : pretraining_base
#   FROZEN batch        : 16
#   Gated               : False
# ⚠ SKIPPED: requires transformers>=4.51.0; installed=4.47.1
#
# ╔══════════════════════════════════════════════════════════════════════════════════════╗
# ║ MODEL 15/25 :: Qwen/Qwen2-1.5B                                                       ║
# ╚══════════════════════════════════════════════════════════════════════════════════════╝
#   Family              : Qwen
#   Generation          : Qwen2
#   Parameters          : 1.5B
#   Architecture        : decoder
#   Training status     : pretrained_base
#   FROZEN batch        : 8
#   Gated               : False
#   Repaired goEmo: removed incompatible labels.npy, recreated labels.npy with consistent dtype
#
# → Preparing Hugging Face model: Qwen/Qwen2-1.5B
#   Preparation attempt 1/4
# Fetching 9 files:   0%|          | 0/9 [00:00<?, ?it/s]
#   ✓ Snapshot ready
#     Attempt time        : 1.14s
#     Total preparation   : 1.22s
#     Checkpoint size     : 2.875 GiB
#     Snapshot            : /Volumes/Amirali/hidden_states/huggingface_cache/hub/models--Qwen--Qwen2-1.5B/snapshots/8a16abf2848eda07cc5253dec660bf1ce007ad7a
#   ✓ Tokenizer loaded in 0.58s Mode=fast
#
# MODEL LOAD ATTEMPT
#   Attempt              : 1/2
#   Path                 : primary
#   Model                : Qwen/Qwen2-1.5B
#   Snapshot             : /Volumes/Amirali/hidden_states/huggingface_cache/hub/models--Qwen--Qwen2-1.5B/snapshots/8a16abf2848eda07cc5253dec660bf1ce007ad7a
#   dtype                : torch.float32
#   device               : cpu
#   SDPA                 : True
#   low_cpu_mem_usage    : True
#   LOADING RESULT
#     Missing keys        : 0
#     Non-core missing    : 0
#     Core missing        : 0
#     Unexpected keys     : 0
#     Mismatched keys     : 0
#     Meta tensors        : 0
#     Core meta           : 0
#     Fatal discrepancy   : False
#
# ✓ MODEL READY
#   Load/probe time       : 81.10s
#   Backend               : sdpa
#   Model device          : cpu
#   Hidden states         : 29
#   Hidden size           : 1536
#
# ────────────────────────────────────────────────────────────────────────────────────────
# DATASET goEmo
# ────────────────────────────────────────────────────────────────────────────────────────
#   Text column         : clean_text
#   Samples             : 54,263
#   Dataset fingerprint : 6302b3ba58f9886999c7
#   Hidden layers       : 29
#   Hidden size         : 1536
#   Output size est.    : 9.00 GiB
#   Pooling             : mean
#   Max length          : 512
#   FROZEN batch        : 8
#   Device              : cpu
#   Runtime diagnostics : /Volumes/Amirali/hidden_states/experiments/baseline_v5_001/models/Qwen/Qwen2-1.5B/datasets/goEmo/metadata/runtime_state.json
#   Existing progress   : 8,984/54,263 (16.56%)
#   Incomplete samples  : 45,279
# goEmo:  17%|#6        | 8984/54263 [00:00<?, ?sample/s]
# [start] starting with 45279 incomplete samples
# [batch] 8984:8992 processed
#
# ────────────────────────────────────────────────────────────────────────────────────────
# RUNTIME / SPEED TELEMETRY :: goEmo
# ────────────────────────────────────────────────────────────────────────────────────────
#   Progress             : 8,992/54,263 (16.57%)
#   Newly computed       : 8
#   Wall time            : 57.81s
#   Throughput           : 0.14 samples/s
#   ETA                  : 90h 51m 59.2s
#   Current stage        : measurement
#
#   LAST BATCH
#     Range              : 8984:8992
#     New samples        : 8
#     Total              : 57.11s
#     Forward            : 55.45s
#     Tokenization       : 0.64s
#     Input transfer     : 0.01s
#     Pooling            : 0.13s
#     Conversion         : 0.11s
#     Memmap write       : 0.11s
#     Flush              : 0.09s
#     Sequence length    : 30
#     Tokens             : 114
#     Token throughput   : 2.00 tokens/s
#
#   ROLLING PERFORMANCE
#     Mean batch         : 57.112s
#     Median batch       : 57.112s
#     P95 batch          : 57.112s
#     Max batch          : 57.112s
#     Slow batches       : 0
#     Current anomaly    : NO
#
#   MEMORY / STORAGE
#     RAM available      : 1.01 GiB
#     Process RSS        : 0.8016090393066406
#     Peak RSS           : 0.80 GiB
#     Minimum RAM        : 1.01 GiB
#     External free      : 1636.18 GiB
#     Successful batches : 1
#     Debug batch output : ON
# ────────────────────────────────────────────────────────────────────────────────────────
# [runtime] periodic runtime telemetry
# [batch] 8992:9000 processed
#
# ────────────────────────────────────────────────────────────────────────────────────────
# RUNTIME / SPEED TELEMETRY :: goEmo
# ────────────────────────────────────────────────────────────────────────────────────────
#   Progress             : 9,000/54,263 (16.59%)
#   Newly computed       : 16
#   Wall time            : 1m 57.4s
#   Throughput           : 0.14 samples/s
#   ETA                  : 92h 15m 49.4s
#   Current stage        : measurement
#
#   LAST BATCH
#     Range              : 8992:9000
#     New samples        : 8
#     Total              : 59.42s
#     Forward            : 57.93s
#     Tokenization       : 0.22s
#     Input transfer     : 0.00s
#     Pooling            : 0.02s
#     Conversion         : 0.04s
#     Memmap write       : 0.42s
#     Flush              : 0.14s
#     Sequence length    : 16
#     Tokens             : 88
#     Token throughput   : 1.48 tokens/s
#
#   ROLLING PERFORMANCE
#     Mean batch         : 58.267s
#     Median batch       : 58.267s
#     P95 batch          : 59.423s
#     Max batch          : 59.423s
#     Slow batches       : 0
#     Current anomaly    : NO
#
#   MEMORY / STORAGE
#     RAM available      : 1.10 GiB
#     Process RSS        : 1.093719482421875
#     Peak RSS           : 1.09 GiB
#     Minimum RAM        : 1.01 GiB
#     External free      : 1636.18 GiB
#     Successful batches : 2
#     Debug batch output : ON
# ────────────────────────────────────────────────────────────────────────────────────────
# [runtime] periodic runtime telemetry
# [batch] 9000:9008 processed
#
# ────────────────────────────────────────────────────────────────────────────────────────
# RUNTIME / SPEED TELEMETRY :: goEmo
# ────────────────────────────────────────────────────────────────────────────────────────
#   Progress             : 9,008/54,263 (16.60%)
#   Newly computed       : 24
#   Wall time            : 2m 52.1s
#   Throughput           : 0.14 samples/s
#   ETA                  : 90h 7m 41.3s
#   Current stage        : measurement
#
#   LAST BATCH
#     Range              : 9000:9008
#     New samples        : 8
#     Total              : 54.52s
#     Forward            : 53.48s
#     Tokenization       : 0.21s
#     Input transfer     : 0.00s
#     Pooling            : 0.02s
#     Conversion         : 0.00s
#     Memmap write       : 0.41s
#     Flush              : 0.06s
#     Sequence length    : 30
#     Tokens             : 145
#     Token throughput   : 2.66 tokens/s
#
#   ROLLING PERFORMANCE
#     Mean batch         : 57.019s
#     Median batch       : 57.112s
#     P95 batch          : 59.423s
#     Max batch          : 59.423s
#     Slow batches       : 0
#     Current anomaly    : NO
#
#   MEMORY / STORAGE
#     RAM available      : 0.97 GiB
#     Process RSS        : 0.959716796875
#     Peak RSS           : 1.09 GiB
#     Minimum RAM        : 0.97 GiB
#     External free      : 1636.18 GiB
#     Successful batches : 3
#     Debug batch output : ON
# ────────────────────────────────────────────────────────────────────────────────────────
# [runtime] periodic runtime telemetry
# [batch] 9008:9016 processed
#
# ────────────────────────────────────────────────────────────────────────────────────────
# RUNTIME / SPEED TELEMETRY :: goEmo
# ────────────────────────────────────────────────────────────────────────────────────────
#   Progress             : 9,016/54,263 (16.62%)
#   Newly computed       : 32
#   Wall time            : 3m 30.1s
#   Throughput           : 0.15 samples/s
#   ETA                  : 82h 30m 55.5s
#   Current stage        : measurement
#
#   LAST BATCH
#     Range              : 9008:9016
#     New samples        : 8
#     Total              : 37.90s
#     Forward            : 36.54s
#     Tokenization       : 0.52s
#     Input transfer     : 0.00s
#     Pooling            : 0.01s
#     Conversion         : 0.00s
#     Memmap write       : 0.44s
#     Flush              : 0.18s
#     Sequence length    : 26
#     Tokens             : 117
#     Token throughput   : 3.09 tokens/s
#
#   ROLLING PERFORMANCE
#     Mean batch         : 52.240s
#     Median batch       : 55.817s
#     P95 batch          : 59.423s
#     Max batch          : 59.423s
#     Slow batches       : 0
#     Current anomaly    : NO
#
#   MEMORY / STORAGE
#     RAM available      : 1.62 GiB
#     Process RSS        : 2.3897857666015625
#     Peak RSS           : 2.39 GiB
#     Minimum RAM        : 0.97 GiB
#     External free      : 1636.18 GiB
#     Successful batches : 4
#     Debug batch output : ON
# ────────────────────────────────────────────────────────────────────────────────────────
# [runtime] periodic runtime telemetry
# [batch] 9016:9024 processed
#
# ────────────────────────────────────────────────────────────────────────────────────────
# RUNTIME / SPEED TELEMETRY :: goEmo
# ────────────────────────────────────────────────────────────────────────────────────────
#   Progress             : 9,024/54,263 (16.63%)
#   Newly computed       : 40
#   Wall time            : 4m 20.3s
#   Throughput           : 0.15 samples/s
#   ETA                  : 81h 45m 46.3s
#   Current stage        : measurement
#
#   LAST BATCH
#     Range              : 9016:9024
#     New samples        : 8
#     Total              : 50.04s
#     Forward            : 48.80s
#     Tokenization       : 0.16s
#     Input transfer     : 0.00s
#     Pooling            : 0.01s
#     Conversion         : 0.00s
#     Memmap write       : 0.41s
#     Flush              : 0.11s
#     Sequence length    : 30
#     Tokens             : 117
#     Token throughput   : 2.34 tokens/s
#
#   ROLLING PERFORMANCE
#     Mean batch         : 51.801s
#     Median batch       : 54.522s
#     P95 batch          : 59.423s
#     Max batch          : 59.423s
#     Slow batches       : 0
#     Current anomaly    : NO
#
#   MEMORY / STORAGE
#     RAM available      : 0.85 GiB
#     Process RSS        : 0.5501251220703125
#     Peak RSS           : 2.39 GiB
#     Minimum RAM        : 0.85 GiB
#     External free      : 1636.18 GiB
#     Successful batches : 5
#     Debug batch output : ON
# ────────────────────────────────────────────────────────────────────────────────────────
# [runtime] periodic runtime telemetry
# [batch] 9024:9032 processed
#
# ────────────────────────────────────────────────────────────────────────────────────────
# RUNTIME / SPEED TELEMETRY :: goEmo
# ────────────────────────────────────────────────────────────────────────────────────────
#   Progress             : 9,032/54,263 (16.64%)
#   Newly computed       : 48
#   Wall time            : 5m 18.8s
#   Throughput           : 0.15 samples/s
#   ETA                  : 83h 26m 10.6s
#   Current stage        : measurement
#
#   LAST BATCH
#     Range              : 9024:9032
#     New samples        : 8
#     Total              : 58.36s
#     Forward            : 56.94s
#     Tokenization       : 0.37s
#     Input transfer     : 0.00s
#     Pooling            : 0.02s
#     Conversion         : 0.00s
#     Memmap write       : 0.41s
#     Flush              : 0.06s
#     Sequence length    : 24
#     Tokens             : 103
#     Token throughput   : 1.76 tokens/s
#
#   ROLLING PERFORMANCE
#     Mean batch         : 52.895s
#     Median batch       : 55.817s
#     P95 batch          : 59.423s
#     Max batch          : 59.423s
#     Slow batches       : 0
#     Current anomaly    : NO
#
#   MEMORY / STORAGE
#     RAM available      : 0.96 GiB
#     Process RSS        : 0.8991203308105469
#     Peak RSS           : 2.39 GiB
#     Minimum RAM        : 0.85 GiB
#     External free      : 1636.18 GiB
#     Successful batches : 6
#     Debug batch output : ON
# ────────────────────────────────────────────────────────────────────────────────────────
# [runtime] periodic runtime telemetry
# [batch] 9032:9040 processed
#
# ────────────────────────────────────────────────────────────────────────────────────────
# RUNTIME / SPEED TELEMETRY :: goEmo
# ────────────────────────────────────────────────────────────────────────────────────────
#   Progress             : 9,040/54,263 (16.66%)
#   Newly computed       : 56
#   Wall time            : 6m 04.8s
#   Throughput           : 0.15 samples/s
#   ETA                  : 81h 49m 17.6s
#   Current stage        : measurement
#
#   LAST BATCH
#     Range              : 9032:9040
#     New samples        : 8
#     Total              : 45.86s
#     Forward            : 44.10s
#     Tokenization       : 0.73s
#     Input transfer     : 0.00s
#     Pooling            : 0.03s
#     Conversion         : 0.00s
#     Memmap write       : 0.41s
#     Flush              : 0.14s
#     Sequence length    : 28
#     Tokens             : 135
#     Token throughput   : 2.94 tokens/s
#
#   ROLLING PERFORMANCE
#     Mean batch         : 51.889s
#     Median batch       : 54.522s
#     P95 batch          : 59.423s
#     Max batch          : 59.423s
#     Slow batches       : 0
#     Current anomaly    : NO
#
#   MEMORY / STORAGE
#     RAM available      : 1.06 GiB
#     Process RSS        : 0.829010009765625
#     Peak RSS           : 2.39 GiB
#     Minimum RAM        : 0.85 GiB
#     External free      : 1636.18 GiB
#     Successful batches : 7
#     Debug batch output : ON
# ────────────────────────────────────────────────────────────────────────────────────────
# [runtime] periodic runtime telemetry
# [batch] 9040:9048 processed
#
# ────────────────────────────────────────────────────────────────────────────────────────
# RUNTIME / SPEED TELEMETRY :: goEmo
# ────────────────────────────────────────────────────────────────────────────────────────
#   Progress             : 9,048/54,263 (16.67%)
#   Newly computed       : 64
#   Wall time            : 6m 51.3s
#   Throughput           : 0.16 samples/s
#   ETA                  : 80h 43m 05.7s
#   Current stage        : measurement
#
#   LAST BATCH
#     Range              : 9040:9048
#     New samples        : 8
#     Total              : 46.36s
#     Forward            : 45.43s
#     Tokenization       : 0.48s
#     Input transfer     : 0.00s
#     Pooling            : 0.02s
#     Conversion         : 0.00s
#     Memmap write       : 0.09s
#     Flush              : 0.07s
#     Sequence length    : 18
#     Tokens             : 80
#     Token throughput   : 1.73 tokens/s
#
#   ROLLING PERFORMANCE
#     Mean batch         : 51.198s
#     Median batch       : 52.283s
#     P95 batch          : 59.423s
#     Max batch          : 59.423s
#     Slow batches       : 0
#     Current anomaly    : NO
#
#   MEMORY / STORAGE
#     RAM available      : 1.20 GiB
#     Process RSS        : 1.5209312438964844
#     Peak RSS           : 2.39 GiB
#     Minimum RAM        : 0.85 GiB
#     External free      : 1636.18 GiB
#     Successful batches : 8
#     Debug batch output : ON
# ────────────────────────────────────────────────────────────────────────────────────────
# [runtime] periodic runtime telemetry
# [batch] 9048:9056 processed
#
# ────────────────────────────────────────────────────────────────────────────────────────
# RUNTIME / SPEED TELEMETRY :: goEmo
# ────────────────────────────────────────────────────────────────────────────────────────
#   Progress             : 9,056/54,263 (16.69%)
#   Newly computed       : 72
#   Wall time            : 7m 54.5s
#   Throughput           : 0.15 samples/s
#   ETA                  : 82h 45m 09.3s
#   Current stage        : measurement
#
#   LAST BATCH
#     Range              : 9048:9056
#     New samples        : 8
#     Total              : 1m 02.9s
#     Forward            : 1m 00.2s
#     Tokenization       : 1.03s
#     Input transfer     : 0.00s
#     Pooling            : 0.06s
#     Conversion         : 0.05s
#     Memmap write       : 0.44s
#     Flush              : 0.10s
#     Sequence length    : 26
#     Tokens             : 136
#     Token throughput   : 2.16 tokens/s
#
#   ROLLING PERFORMANCE
#     Mean batch         : 52.498s
#     Median batch       : 54.522s
#     P95 batch          : 62.900s
#     Max batch          : 62.900s
#     Slow batches       : 0
#     Current anomaly    : NO
#
#   MEMORY / STORAGE
#     RAM available      : 0.88 GiB
#     Process RSS        : 0.40433502197265625
#     Peak RSS           : 2.39 GiB
#     Minimum RAM        : 0.85 GiB
#     External free      : 1636.18 GiB
#     Successful batches : 9
#     Debug batch output : ON
# ────────────────────────────────────────────────────────────────────────────────────────
# [runtime] periodic runtime telemetry
# [batch] 9056:9064 processed
#
# ────────────────────────────────────────────────────────────────────────────────────────
# RUNTIME / SPEED TELEMETRY :: goEmo
# ────────────────────────────────────────────────────────────────────────────────────────
#   Progress             : 9,064/54,263 (16.70%)
#   Newly computed       : 80
#   Wall time            : 9m 25.2s
#   Throughput           : 0.14 samples/s
#   ETA                  : 88h 42m 19.4s
#   Current stage        : measurement
#
#   LAST BATCH
#     Range              : 9056:9064
#     New samples        : 8
#     Total              : 1m 30.4s
#     Forward            : 1m 27.6s
#     Tokenization       : 0.70s
#     Input transfer     : 0.00s
#     Pooling            : 0.09s
#     Conversion         : 0.08s
#     Memmap write       : 0.38s
#     Flush              : 0.18s
#     Sequence length    : 32
#     Tokens             : 97
#     Token throughput   : 1.07 tokens/s
#
#   ROLLING PERFORMANCE
#     Mean batch         : 56.289s
#     Median batch       : 55.817s
#     P95 batch          : 90.404s
#     Max batch          : 90.404s
#     Slow batches       : 0
#     Current anomaly    : NO
#
#   MEMORY / STORAGE
#     RAM available      : 0.75 GiB
#     Process RSS        : 0.2911796569824219
#     Peak RSS           : 2.39 GiB
#     Minimum RAM        : 0.75 GiB
#     External free      : 1636.18 GiB
#     Successful batches : 10
#     Debug batch output : ON
# ────────────────────────────────────────────────────────────────────────────────────────
# [runtime] periodic runtime telemetry
# [batch] 9064:9072 processed
#
# ────────────────────────────────────────────────────────────────────────────────────────
# RUNTIME / SPEED TELEMETRY :: goEmo
# ────────────────────────────────────────────────────────────────────────────────────────
#   Progress             : 9,072/54,263 (16.72%)
#   Newly computed       : 88
#   Wall time            : 10m 32.3s
#   Throughput           : 0.14 samples/s
#   ETA                  : 90h 11m 46.5s
#   Current stage        : measurement
#
#   LAST BATCH
#     Range              : 9064:9072
#     New samples        : 8
#     Total              : 1m 06.8s
#     Forward            : 1m 04.7s
#     Tokenization       : 1.08s
#     Input transfer     : 0.00s
#     Pooling            : 0.01s
#     Conversion         : 0.01s
#     Memmap write       : 0.43s
#     Flush              : 0.20s
#     Sequence length    : 22
#     Tokens             : 117
#     Token throughput   : 1.75 tokens/s
#
#   ROLLING PERFORMANCE
#     Mean batch         : 57.247s
#     Median batch       : 57.112s
#     P95 batch          : 90.404s
#     Max batch          : 90.404s
#     Slow batches       : 0
#     Current anomaly    : NO
#
#   MEMORY / STORAGE
#     RAM available      : 0.95 GiB
#     Process RSS        : 0.831451416015625
#     Peak RSS           : 2.39 GiB
#     Minimum RAM        : 0.75 GiB
#     External free      : 1636.18 GiB
#     Successful batches : 11
#     Debug batch output : ON
# ────────────────────────────────────────────────────────────────────────────────────────
# [runtime] periodic runtime telemetry
# [batch] 9072:9080 processed
#
# ────────────────────────────────────────────────────────────────────────────────────────
# RUNTIME / SPEED TELEMETRY :: goEmo
# ────────────────────────────────────────────────────────────────────────────────────────
#   Progress             : 9,080/54,263 (16.73%)
#   Newly computed       : 96
#   Wall time            : 11m 39.0s
#   Throughput           : 0.14 samples/s
#   ETA                  : 91h 23m 12.2s
#   Current stage        : measurement
#
#   LAST BATCH
#     Range              : 9072:9080
#     New samples        : 8
#     Total              : 1m 06.4s
#     Forward            : 1m 04.0s
#     Tokenization       : 0.66s
#     Input transfer     : 0.00s
#     Pooling            : 0.08s
#     Conversion         : 0.01s
#     Memmap write       : 0.36s
#     Flush              : 0.16s
#     Sequence length    : 25
#     Tokens             : 114
#     Token throughput   : 1.72 tokens/s
#
#   ROLLING PERFORMANCE
#     Mean batch         : 58.009s
#     Median batch       : 57.738s
#     P95 batch          : 90.404s
#     Max batch          : 90.404s
#     Slow batches       : 0
#     Current anomaly    : NO
#
#   MEMORY / STORAGE
#     RAM available      : 0.90 GiB
#     Process RSS        : 0.3607902526855469
#     Peak RSS           : 2.39 GiB
#     Minimum RAM        : 0.75 GiB
#     External free      : 1636.18 GiB
#     Successful batches : 12
#     Debug batch output : ON
# ────────────────────────────────────────────────────────────────────────────────────────
# [runtime] periodic runtime telemetry
# [batch] 9080:9088 processed
#
# ────────────────────────────────────────────────────────────────────────────────────────
# RUNTIME / SPEED TELEMETRY :: goEmo
# ────────────────────────────────────────────────────────────────────────────────────────
#   Progress             : 9,088/54,263 (16.75%)
#   Newly computed       : 104
#   Wall time            : 12m 37.9s
#   Throughput           : 0.14 samples/s
#   ETA                  : 91h 26m 51.5s
#   Current stage        : measurement
#
#   LAST BATCH
#     Range              : 9080:9088
#     New samples        : 8
#     Total              : 58.70s
#     Forward            : 57.10s
#     Tokenization       : 1.07s
#     Input transfer     : 0.00s
#     Pooling            : 0.03s
#     Conversion         : 0.00s
#     Memmap write       : 0.04s
#     Flush              : 0.13s
#     Sequence length    : 30
#     Tokens             : 145
#     Token throughput   : 2.47 tokens/s
#
#   ROLLING PERFORMANCE
#     Mean batch         : 58.062s
#     Median batch       : 58.364s
#     P95 batch          : 90.404s
#     Max batch          : 90.404s
#     Slow batches       : 0
#     Current anomaly    : NO
#
#   MEMORY / STORAGE
#     RAM available      : 1.01 GiB
#     Process RSS        : 1.1291961669921875
#     Peak RSS           : 2.39 GiB
#     Minimum RAM        : 0.75 GiB
#     External free      : 1636.18 GiB
#     Successful batches : 13
#     Debug batch output : ON
# ────────────────────────────────────────────────────────────────────────────────────────
# [runtime] periodic runtime telemetry
# [batch] 9088:9096 processed
#
# ────────────────────────────────────────────────────────────────────────────────────────
# RUNTIME / SPEED TELEMETRY :: goEmo
# ────────────────────────────────────────────────────────────────────────────────────────
#   Progress             : 9,096/54,263 (16.76%)
#   Newly computed       : 112
#   Wall time            : 13m 16.4s
#   Throughput           : 0.14 samples/s
#   ETA                  : 89h 12m 58.6s
#   Current stage        : measurement
#
#   LAST BATCH
#     Range              : 9088:9096
#     New samples        : 8
#     Total              : 38.39s
#     Forward            : 36.86s
#     Tokenization       : 0.66s
#     Input transfer     : 0.00s
#     Pooling            : 0.01s
#     Conversion         : 0.00s
#     Memmap write       : 0.33s
#     Flush              : 0.07s
#     Sequence length    : 30
#     Tokens             : 119
#     Token throughput   : 3.10 tokens/s
#
#   ROLLING PERFORMANCE
#     Mean batch         : 56.657s
#     Median batch       : 57.738s
#     P95 batch          : 90.404s
#     Max batch          : 90.404s
#     Slow batches       : 0
#     Current anomaly    : NO
#
#   MEMORY / STORAGE
#     RAM available      : 1.14 GiB
#     Process RSS        : 0.8500709533691406
#     Peak RSS           : 2.39 GiB
#     Minimum RAM        : 0.75 GiB
#     External free      : 1636.18 GiB
#     Successful batches : 14
#     Debug batch output : ON
# ────────────────────────────────────────────────────────────────────────────────────────
# [runtime] periodic runtime telemetry
# [batch] 9096:9104 processed
#
# ────────────────────────────────────────────────────────────────────────────────────────
# RUNTIME / SPEED TELEMETRY :: goEmo
# ────────────────────────────────────────────────────────────────────────────────────────
#   Progress             : 9,104/54,263 (16.78%)
#   Newly computed       : 120
#   Wall time            : 13m 38.3s
#   Throughput           : 0.15 samples/s
#   ETA                  : 85h 32m 04.5s
#   Current stage        : measurement
#
#   LAST BATCH
#     Range              : 9096:9104
#     New samples        : 8
#     Total              : 21.52s
#     Forward            : 20.02s
#     Tokenization       : 0.91s
#     Input transfer     : 0.00s
#     Pooling            : 0.01s
#     Conversion         : 0.00s
#     Memmap write       : 0.34s
#     Flush              : 0.05s
#     Sequence length    : 31
#     Tokens             : 131
#     Token throughput   : 6.09 tokens/s
#
#   ROLLING PERFORMANCE
#     Mean batch         : 54.315s
#     Median batch       : 57.112s
#     P95 batch          : 90.404s
#     Max batch          : 90.404s
#     Slow batches       : 0
#     Current anomaly    : NO
#
#   MEMORY / STORAGE
#     RAM available      : 1.31 GiB
#     Process RSS        : 1.8693504333496094
#     Peak RSS           : 2.39 GiB
#     Minimum RAM        : 0.75 GiB
#     External free      : 1636.18 GiB
#     Successful batches : 15
#     Debug batch output : ON
# ────────────────────────────────────────────────────────────────────────────────────────
# [runtime] periodic runtime telemetry
# [batch] 9104:9112 processed
#
# ────────────────────────────────────────────────────────────────────────────────────────
# RUNTIME / SPEED TELEMETRY :: goEmo
# ────────────────────────────────────────────────────────────────────────────────────────
#   Progress             : 9,112/54,263 (16.79%)
#   Newly computed       : 128
#   Wall time            : 14m 32.7s
#   Throughput           : 0.15 samples/s
#   ETA                  : 85h 30m 46.0s
#   Current stage        : measurement
#
#   LAST BATCH
#     Range              : 9104:9112
#     New samples        : 8
#     Total              : 54.23s
#     Forward            : 52.87s
#     Tokenization       : 0.44s
#     Input transfer     : 0.00s
#     Pooling            : 0.02s
#     Conversion         : 0.00s
#     Memmap write       : 0.43s
#     Flush              : 0.06s
#     Sequence length    : 26
#     Tokens             : 132
#     Token throughput   : 2.43 tokens/s
#
#   ROLLING PERFORMANCE
#     Mean batch         : 54.310s
#     Median batch       : 55.817s
#     P95 batch          : 90.404s
#     Max batch          : 90.404s
#     Slow batches       : 0
#     Current anomaly    : NO
#
#   MEMORY / STORAGE
#     RAM available      : 1.18 GiB
#     Process RSS        : 1.2259254455566406
#     Peak RSS           : 2.39 GiB
#     Minimum RAM        : 0.75 GiB
#     External free      : 1636.18 GiB
#     Successful batches : 16
#     Debug batch output : ON
# ────────────────────────────────────────────────────────────────────────────────────────
# [runtime] periodic runtime telemetry
# [batch] 9112:9120 processed
#
# ────────────────────────────────────────────────────────────────────────────────────────
# RUNTIME / SPEED TELEMETRY :: goEmo
# ────────────────────────────────────────────────────────────────────────────────────────
#   Progress             : 9,120/54,263 (16.81%)
#   Newly computed       : 136
#   Wall time            : 14m 47.9s
#   Throughput           : 0.15 samples/s
#   ETA                  : 81h 52m 01.8s
#   Current stage        : measurement
#
#   LAST BATCH
#     Range              : 9112:9120
#     New samples        : 8
#     Total              : 15.02s
#     Forward            : 13.48s
#     Tokenization       : 1.28s
#     Input transfer     : 0.00s
#     Pooling            : 0.01s
#     Conversion         : 0.00s
#     Memmap write       : 0.08s
#     Flush              : 0.05s
#     Sequence length    : 29
#     Tokens             : 147
#     Token throughput   : 9.78 tokens/s
#
#   ROLLING PERFORMANCE
#     Mean batch         : 51.999s
#     Median batch       : 54.522s
#     P95 batch          : 90.404s
#     Max batch          : 90.404s
#     Slow batches       : 0
#     Current anomaly    : NO
#
#   MEMORY / STORAGE
#     RAM available      : 2.87 GiB
#     Process RSS        : 4.868080139160156
#     Peak RSS           : 4.87 GiB
#     Minimum RAM        : 0.75 GiB
#     External free      : 1636.18 GiB
#     Successful batches : 17
#     Debug batch output : ON
# ────────────────────────────────────────────────────────────────────────────────────────
# [runtime] periodic runtime telemetry
# [batch] 9120:9128 processed
# [batch] 9128:9136 processed
#
# ────────────────────────────────────────────────────────────────────────────────────────
# RUNTIME / SPEED TELEMETRY :: goEmo
# ────────────────────────────────────────────────────────────────────────────────────────
#   Progress             : 9,136/54,263 (16.84%)
#   Newly computed       : 152
#   Wall time            : 15m 58.9s
#   Throughput           : 0.16 samples/s
#   ETA                  : 79h 4m 52.5s
#   Current stage        : measurement
#
#   LAST BATCH
#     Range              : 9128:9136
#     New samples        : 8
#     Total              : 58.95s
#     Forward            : 58.04s
#     Tokenization       : 0.23s
#     Input transfer     : 0.00s
#     Pooling            : 0.01s
#     Conversion         : 0.00s
#     Memmap write       : 0.35s
#     Flush              : 0.08s
#     Sequence length    : 25
#     Tokens             : 110
#     Token throughput   : 1.87 tokens/s
#
#   ROLLING PERFORMANCE
#     Mean batch         : 50.250s
#     Median batch       : 54.522s
#     P95 batch          : 90.404s
#     Max batch          : 90.404s
#     Slow batches       : 0
#     Current anomaly    : NO
#
#   MEMORY / STORAGE
#     RAM available      : 1.13 GiB
#     Process RSS        : 0.8991279602050781
#     Peak RSS           : 4.87 GiB
#     Minimum RAM        : 0.75 GiB
#     External free      : 1636.18 GiB
#     Successful batches : 19
#     Debug batch output : ON
# ────────────────────────────────────────────────────────────────────────────────────────
# [runtime] periodic runtime telemetry
# [batch] 9136:9144 processed
#
# ────────────────────────────────────────────────────────────────────────────────────────
# RUNTIME / SPEED TELEMETRY :: goEmo
# ────────────────────────────────────────────────────────────────────────────────────────
#   Progress             : 9,144/54,263 (16.85%)
#   Newly computed       : 160
#   Wall time            : 17m 09.2s
#   Throughput           : 0.16 samples/s
#   ETA                  : 80h 37m 02.6s
#   Current stage        : measurement
#
#   LAST BATCH
#     Range              : 9136:9144
#     New samples        : 8
#     Total              : 1m 10.0s
#     Forward            : 1m 08.6s
#     Tokenization       : 0.32s
#     Input transfer     : 0.00s
#     Pooling            : 0.03s
#     Conversion         : 0.00s
#     Memmap write       : 0.44s
#     Flush              : 0.05s
#     Sequence length    : 23
#     Tokens             : 122
#     Token throughput   : 1.74 tokens/s
#
#   ROLLING PERFORMANCE
#     Mean batch         : 51.240s
#     Median batch       : 55.817s
#     P95 batch          : 70.046s
#     Max batch          : 90.404s
#     Slow batches       : 0
#     Current anomaly    : NO
#
#   MEMORY / STORAGE
#     RAM available      : 0.97 GiB
#     Process RSS        : 0.9442634582519531
#     Peak RSS           : 4.87 GiB
#     Minimum RAM        : 0.75 GiB
#     External free      : 1636.18 GiB
#     Successful batches : 20
#     Debug batch output : ON
# ────────────────────────────────────────────────────────────────────────────────────────
# [runtime] periodic runtime telemetry
# [batch] 9144:9152 processed
#
# ────────────────────────────────────────────────────────────────────────────────────────
# RUNTIME / SPEED TELEMETRY :: goEmo
# ────────────────────────────────────────────────────────────────────────────────────────
#   Progress             : 9,152/54,263 (16.87%)
#   Newly computed       : 168
#   Wall time            : 18m 09.7s
#   Throughput           : 0.15 samples/s
#   ETA                  : 81h 16m 50.9s
#   Current stage        : measurement
#
#   LAST BATCH
#     Range              : 9144:9152
#     New samples        : 8
#     Total              : 1m 00.4s
#     Forward            : 58.99s
#     Tokenization       : 0.46s
#     Input transfer     : 0.00s
#     Pooling            : 0.10s
#     Conversion         : 0.00s
#     Memmap write       : 0.42s
#     Flush              : 0.05s
#     Sequence length    : 31
#     Tokens             : 130
#     Token throughput   : 2.15 tokens/s
#
#   ROLLING PERFORMANCE
#     Mean batch         : 51.405s
#     Median batch       : 56.443s
#     P95 batch          : 70.046s
#     Max batch          : 90.404s
#     Slow batches       : 0
#     Current anomaly    : NO
#
#   MEMORY / STORAGE
#     RAM available      : 1.13 GiB
#     Process RSS        : 1.3840904235839844
#     Peak RSS           : 4.87 GiB
#     Minimum RAM        : 0.75 GiB
#     External free      : 1636.18 GiB
#     Successful batches : 21
#     Debug batch output : ON
# ────────────────────────────────────────────────────────────────────────────────────────
# [runtime] periodic runtime telemetry
# [batch] 9152:9160 processed
#
# ────────────────────────────────────────────────────────────────────────────────────────
# RUNTIME / SPEED TELEMETRY :: goEmo
# ────────────────────────────────────────────────────────────────────────────────────────
#   Progress             : 9,160/54,263 (16.88%)
#   Newly computed       : 176
#   Wall time            : 19m 10.2s
#   Throughput           : 0.15 samples/s
#   ETA                  : 81h 52m 28.3s
#   Current stage        : measurement
#
#   LAST BATCH
#     Range              : 9152:9160
#     New samples        : 8
#     Total              : 1m 00.3s
#     Forward            : 58.78s
#     Tokenization       : 0.60s
#     Input transfer     : 0.00s
#     Pooling            : 0.03s
#     Conversion         : 0.00s
#     Memmap write       : 0.60s
#     Flush              : 0.09s
#     Sequence length    : 29
#     Tokens             : 110
#     Token throughput   : 1.82 tokens/s
#
#   ROLLING PERFORMANCE
#     Mean batch         : 51.449s
#     Median batch       : 56.443s
#     P95 batch          : 70.046s
#     Max batch          : 90.404s
#     Slow batches       : 0
#     Current anomaly    : NO
#
#   MEMORY / STORAGE
#     RAM available      : 1.37 GiB
#     Process RSS        : 1.2510910034179688
#     Peak RSS           : 4.87 GiB
#     Minimum RAM        : 0.75 GiB
#     External free      : 1636.18 GiB
#     Successful batches : 22
#     Debug batch output : ON
# ────────────────────────────────────────────────────────────────────────────────────────
# [runtime] periodic runtime telemetry
# [batch] 9160:9168 processed
#
# ────────────────────────────────────────────────────────────────────────────────────────
# RUNTIME / SPEED TELEMETRY :: goEmo
# ────────────────────────────────────────────────────────────────────────────────────────
#   Progress             : 9,168/54,263 (16.90%)
#   Newly computed       : 184
#   Wall time            : 20m 05.6s
#   Throughput           : 0.15 samples/s
#   ETA                  : 82h 4m 29.3s
#   Current stage        : measurement
#
#   LAST BATCH
#     Range              : 9160:9168
#     New samples        : 8
#     Total              : 55.30s
#     Forward            : 53.95s
# ...
#     New samples        : 8
#     Total              : 1m 04.0s
#     Forward            : 1m 02.7s
#     Tokenization       : 0.43s
#     Input transfer     : 0.00s
#     Pooling            : 0.01s
#     Conversion         : 0.00s
#     Memmap write       : 0.35s
#     Flush              : 0.09s
#     Sequence length    : 29
#     Tokens             : 144
#     Token throughput   : 2.25 tokens/s
#
#   ROLLING PERFORMANCE
#     Mean batch         : 51.906s
#     Median batch       : 55.232s
#     P95 batch          : 66.165s
#     Max batch          : 66.400s
#     Slow batches       : 0
#     Current anomaly    : NO
#
#   MEMORY / STORAGE
#     RAM available      : 1.28 GiB
#     Process RSS        : 1.4688224792480469
#     Peak RSS           : 4.87 GiB
#     Minimum RAM        : 0.67 GiB
#     External free      : 1636.18 GiB
#     Successful batches : 127
#     Debug batch output : ON
# ────────────────────────────────────────────────────────────────────────────────────────
# [runtime] periodic runtime telemetry
# [batch] 10000:10008 processed
#
# ────────────────────────────────────────────────────────────────────────────────────────
# RUNTIME / SPEED TELEMETRY :: goEmo
# ────────────────────────────────────────────────────────────────────────────────────────
#   Progress             : 10,008/54,263 (18.44%)
#   Newly computed       : 1,024
#   Wall time            : 1h 50m 57.2s
#   Throughput           : 0.15 samples/s
#   ETA                  : 79h 55m 09.9s
#   Current stage        : measurement
#
#   LAST BATCH
#     Range              : 10000:10008
#     New samples        : 8
#     Total              : 1m 00.6s
#     Forward            : 59.07s
#     Tokenization       : 0.23s
#     Input transfer     : 0.00s
#     Pooling            : 0.01s
#     Conversion         : 0.01s
#     Memmap write       : 0.36s
#     Flush              : 0.15s
#     Sequence length    : 16
#     Tokens             : 105
#     Token throughput   : 1.73 tokens/s
#
#   ROLLING PERFORMANCE
#     Mean batch         : 51.767s
#     Median batch       : 55.232s
#     P95 batch          : 66.165s
#     Max batch          : 66.400s
#     Slow batches       : 0
#     Current anomaly    : NO
#
#   MEMORY / STORAGE
#     RAM available      : 1.10 GiB
#     Process RSS        : 0.8096961975097656
#     Peak RSS           : 4.87 GiB
#     Minimum RAM        : 0.67 GiB
#     External free      : 1636.18 GiB
#     Successful batches : 128
#     Debug batch output : ON
# ────────────────────────────────────────────────────────────────────────────────────────
# [runtime] periodic runtime telemetry
# [batch] 10008:10016 processed
#
# ────────────────────────────────────────────────────────────────────────────────────────
# RUNTIME / SPEED TELEMETRY :: goEmo
# ────────────────────────────────────────────────────────────────────────────────────────
#   Progress             : 10,016/54,263 (18.46%)
#   Newly computed       : 1,032
#   Wall time            : 1h 53m 12.9s
#   Throughput           : 0.15 samples/s
#   ETA                  : 80h 54m 03.6s
#   Current stage        : measurement
#
#   LAST BATCH
#     Range              : 10008:10016
#     New samples        : 8
#     Total              : 2m 15.5s
#     Forward            : 2m 14.0s
#     Tokenization       : 0.18s
#     Input transfer     : 0.00s
#     Pooling            : 0.01s
#     Conversion         : 0.01s
#     Memmap write       : 0.61s
#     Flush              : 0.11s
#     Sequence length    : 21
#     Tokens             : 113
#     Token throughput   : 0.83 tokens/s
#
#   ROLLING PERFORMANCE
#     Mean batch         : 55.236s
#     Median batch       : 55.232s
#     P95 batch          : 66.400s
#     Max batch          : 135.541s
#     Slow batches       : 1
#     Current anomaly    : YES (x2.45)
#
#   MEMORY / STORAGE
#     RAM available      : 0.96 GiB
#     Process RSS        : 0.6390266418457031
#     Peak RSS           : 4.87 GiB
#     Minimum RAM        : 0.67 GiB
#     External free      : 1636.18 GiB
#     Successful batches : 129
#     Debug batch output : ON
# ────────────────────────────────────────────────────────────────────────────────────────
# [runtime] periodic runtime telemetry
# [batch] 10016:10024 processed
#
# ────────────────────────────────────────────────────────────────────────────────────────
# RUNTIME / SPEED TELEMETRY :: goEmo
# ────────────────────────────────────────────────────────────────────────────────────────
#   Progress             : 10,024/54,263 (18.47%)
#   Newly computed       : 1,040
#   Wall time            : 1h 54m 12.2s
#   Throughput           : 0.15 samples/s
#   ETA                  : 80h 57m 54.8s
#   Current stage        : measurement
#
#   LAST BATCH
#     Range              : 10016:10024
#     New samples        : 8
#     Total              : 59.21s
#     Forward            : 57.40s
#     Tokenization       : 0.91s
#     Input transfer     : 0.00s
#     Pooling            : 0.01s
#     Conversion         : 0.01s
#     Memmap write       : 0.34s
#     Flush              : 0.07s
#     Sequence length    : 30
#     Tokens             : 132
#     Token throughput   : 2.23 tokens/s
#
#   ROLLING PERFORMANCE
#     Mean batch         : 55.183s
#     Median batch       : 55.232s
#     P95 batch          : 66.400s
#     Max batch          : 135.541s
#     Slow batches       : 1
#     Current anomaly    : NO
#
#   MEMORY / STORAGE
#     RAM available      : 0.97 GiB
#     Process RSS        : 0.8741455078125
#     Peak RSS           : 4.87 GiB
#     Minimum RAM        : 0.67 GiB
#     External free      : 1636.18 GiB
#     Successful batches : 130
#     Debug batch output : ON
# ────────────────────────────────────────────────────────────────────────────────────────
# [runtime] periodic runtime telemetry
# [batch] 10024:10032 processed
#
# ────────────────────────────────────────────────────────────────────────────────────────
# RUNTIME / SPEED TELEMETRY :: goEmo
# ────────────────────────────────────────────────────────────────────────────────────────
#   Progress             : 10,032/54,263 (18.49%)
#   Newly computed       : 1,048
#   Wall time            : 1h 55m 14.9s
#   Throughput           : 0.15 samples/s
#   ETA                  : 81h 4m 05.9s
#   Current stage        : measurement
#
#   LAST BATCH
#     Range              : 10024:10032
#     New samples        : 8
#     Total              : 1m 02.7s
#     Forward            : 1m 00.9s
#     Tokenization       : 0.92s
#     Input transfer     : 0.00s
#     Pooling            : 0.01s
#     Conversion         : 0.00s
#     Memmap write       : 0.34s
#     Flush              : 0.07s
#     Sequence length    : 29
#     Tokens             : 148
#     Token throughput   : 2.36 tokens/s
#
#   ROLLING PERFORMANCE
#     Mean batch         : 56.349s
#     Median batch       : 56.430s
#     P95 batch          : 66.400s
#     Max batch          : 135.541s
#     Slow batches       : 1
#     Current anomaly    : NO
#
#   MEMORY / STORAGE
#     RAM available      : 0.97 GiB
#     Process RSS        : 0.8036231994628906
#     Peak RSS           : 4.87 GiB
#     Minimum RAM        : 0.67 GiB
#     External free      : 1636.18 GiB
#     Successful batches : 131
#     Debug batch output : ON
# ────────────────────────────────────────────────────────────────────────────────────────
# [runtime] periodic runtime telemetry
# [batch] 10032:10040 processed
#
# ────────────────────────────────────────────────────────────────────────────────────────
# RUNTIME / SPEED TELEMETRY :: goEmo
# ────────────────────────────────────────────────────────────────────────────────────────
#   Progress             : 10,040/54,263 (18.50%)
#   Newly computed       : 1,056
#   Wall time            : 1h 56m 02.1s
#   Throughput           : 0.15 samples/s
#   ETA                  : 80h 59m 19.1s
#   Current stage        : measurement
#
#   LAST BATCH
#     Range              : 10032:10040
#     New samples        : 8
#     Total              : 47.14s
#     Forward            : 46.39s
#     Tokenization       : 0.21s
#     Input transfer     : 0.00s
#     Pooling            : 0.02s
#     Conversion         : 0.00s
#     Memmap write       : 0.35s
#     Flush              : 0.05s
#     Sequence length    : 32
#     Tokens             : 156
#     Token throughput   : 3.31 tokens/s
#
#   ROLLING PERFORMANCE
#     Mean batch         : 55.601s
#     Median batch       : 55.232s
#     P95 batch          : 66.400s
#     Max batch          : 135.541s
#     Slow batches       : 1
#     Current anomaly    : NO
#
#   MEMORY / STORAGE
#     RAM available      : 0.95 GiB
#     Process RSS        : 0.9707374572753906
#     Peak RSS           : 4.87 GiB
#     Minimum RAM        : 0.67 GiB
#     External free      : 1636.18 GiB
#     Successful batches : 132
#     Debug batch output : ON
# ────────────────────────────────────────────────────────────────────────────────────────
# [runtime] periodic runtime telemetry
# [batch] 10040:10048 processed
#
# ────────────────────────────────────────────────────────────────────────────────────────
# RUNTIME / SPEED TELEMETRY :: goEmo
# ────────────────────────────────────────────────────────────────────────────────────────
#   Progress             : 10,048/54,263 (18.52%)
#   Newly computed       : 1,064
#   Wall time            : 1h 56m 30.4s
#   Throughput           : 0.15 samples/s
#   ETA                  : 80h 41m 30.2s
#   Current stage        : measurement
#
#   LAST BATCH
#     Range              : 10040:10048
#     New samples        : 8
#     Total              : 28.22s
#     Forward            : 27.44s
#     Tokenization       : 0.26s
#     Input transfer     : 0.01s
#     Pooling            : 0.01s
#     Conversion         : 0.00s
#     Memmap write       : 0.35s
#     Flush              : 0.04s
#     Sequence length    : 29
#     Tokens             : 120
#     Token throughput   : 4.25 tokens/s
#
#   ROLLING PERFORMANCE
#     Mean batch         : 55.542s
#     Median batch       : 55.232s
#     P95 batch          : 66.400s
#     Max batch          : 135.541s
#     Slow batches       : 1
#     Current anomaly    : NO
#
#   MEMORY / STORAGE
#     RAM available      : 1.07 GiB
#     Process RSS        : 1.2224273681640625
#     Peak RSS           : 4.87 GiB
#     Minimum RAM        : 0.67 GiB
#     External free      : 1636.18 GiB
#     Successful batches : 133
#     Debug batch output : ON
# ────────────────────────────────────────────────────────────────────────────────────────
# [runtime] periodic runtime telemetry
# [batch] 10048:10056 processed
#
# ────────────────────────────────────────────────────────────────────────────────────────
# RUNTIME / SPEED TELEMETRY :: goEmo
# ────────────────────────────────────────────────────────────────────────────────────────
#   Progress             : 10,056/54,263 (18.53%)
#   Newly computed       : 1,072
#   Wall time            : 1h 56m 55.7s
#   Throughput           : 0.15 samples/s
#   ETA                  : 80h 21m 54.1s
#   Current stage        : measurement
#
#   LAST BATCH
#     Range              : 10048:10056
#     New samples        : 8
#     Total              : 25.25s
#     Forward            : 24.40s
#     Tokenization       : 0.16s
#     Input transfer     : 0.00s
#     Pooling            : 0.01s
#     Conversion         : 0.00s
#     Memmap write       : 0.38s
#     Flush              : 0.04s
#     Sequence length    : 28
#     Tokens             : 126
#     Token throughput   : 4.99 tokens/s
#
#   ROLLING PERFORMANCE
#     Mean batch         : 54.739s
#     Median batch       : 55.232s
#     P95 batch          : 66.400s
#     Max batch          : 135.541s
#     Slow batches       : 1
#     Current anomaly    : NO
#
#   MEMORY / STORAGE
#     RAM available      : 0.84 GiB
#     Process RSS        : 0.9327163696289062
#     Peak RSS           : 4.87 GiB
#     Minimum RAM        : 0.67 GiB
#     External free      : 1636.18 GiB
#     Successful batches : 134
#     Debug batch output : ON
# ────────────────────────────────────────────────────────────────────────────────────────
# [runtime] periodic runtime telemetry
# [batch] 10056:10064 processed
#
# ────────────────────────────────────────────────────────────────────────────────────────
# RUNTIME / SPEED TELEMETRY :: goEmo
# ────────────────────────────────────────────────────────────────────────────────────────
#   Progress             : 10,064/54,263 (18.55%)
#   Newly computed       : 1,080
#   Wall time            : 1h 58m 04.1s
#   Throughput           : 0.15 samples/s
#   ETA                  : 80h 31m 57.5s
#   Current stage        : measurement
#
#   LAST BATCH
#     Range              : 10056:10064
#     New samples        : 8
#     Total              : 1m 08.1s
#     Forward            : 1m 07.2s
#     Tokenization       : 0.23s
#     Input transfer     : 0.00s
#     Pooling            : 0.01s
#     Conversion         : 0.00s
#     Memmap write       : 0.35s
#     Flush              : 0.07s
#     Sequence length    : 14
#     Tokens             : 81
#     Token throughput   : 1.19 tokens/s
#
#   ROLLING PERFORMANCE
#     Mean batch         : 55.061s
#     Median batch       : 55.232s
#     P95 batch          : 68.135s
#     Max batch          : 135.541s
#     Slow batches       : 1
#     Current anomaly    : NO
#
#   MEMORY / STORAGE
#     RAM available      : 1.01 GiB
#     Process RSS        : 0.7961044311523438
#     Peak RSS           : 4.87 GiB
#     Minimum RAM        : 0.67 GiB
#     External free      : 1636.18 GiB
#     Successful batches : 135
#     Debug batch output : ON
# ────────────────────────────────────────────────────────────────────────────────────────
# [runtime] periodic runtime telemetry
# [batch] 10064:10072 processed
#
# ────────────────────────────────────────────────────────────────────────────────────────
# RUNTIME / SPEED TELEMETRY :: goEmo
# ────────────────────────────────────────────────────────────────────────────────────────
#   Progress             : 10,072/54,263 (18.56%)
#   Newly computed       : 1,088
#   Wall time            : 1h 59m 05.8s
#   Throughput           : 0.15 samples/s
#   ETA                  : 80h 37m 20.5s
#   Current stage        : measurement
#
#   LAST BATCH
#     Range              : 10064:10072
#     New samples        : 8
#     Total              : 1m 01.6s
#     Forward            : 59.76s
#     Tokenization       : 0.77s
#     Input transfer     : 0.00s
#     Pooling            : 0.01s
#     Conversion         : 0.01s
#     Memmap write       : 0.54s
#     Flush              : 0.09s
#     Sequence length    : 31
#     Tokens             : 135
#     Token throughput   : 2.19 tokens/s
#
#   ROLLING PERFORMANCE
#     Mean batch         : 55.188s
#     Median batch       : 55.232s
#     P95 batch          : 68.135s
#     Max batch          : 135.541s
#     Slow batches       : 1
#     Current anomaly    : NO
#
#   MEMORY / STORAGE
#     RAM available      : 1.11 GiB
#     Process RSS        : 0.9417610168457031
#     Peak RSS           : 4.87 GiB
#     Minimum RAM        : 0.67 GiB
#     External free      : 1636.18 GiB
#     Successful batches : 136
#     Debug batch output : ON
# ────────────────────────────────────────────────────────────────────────────────────────
# [runtime] periodic runtime telemetry
# [batch] 10072:10080 processed
#
# ────────────────────────────────────────────────────────────────────────────────────────
# RUNTIME / SPEED TELEMETRY :: goEmo
# ────────────────────────────────────────────────────────────────────────────────────────
#   Progress             : 10,080/54,263 (18.58%)
#   Newly computed       : 1,096
#   Wall time            : 2h 0m 37.9s
#   Throughput           : 0.15 samples/s
#   ETA                  : 81h 3m 02.9s
#   Current stage        : measurement
#
#   LAST BATCH
#     Range              : 10072:10080
#     New samples        : 8
#     Total              : 1m 31.8s
#     Forward            : 1m 30.2s
#     Tokenization       : 0.39s
#     Input transfer     : 0.00s
#     Pooling            : 0.07s
#     Conversion         : 0.07s
#     Memmap write       : 0.08s
#     Flush              : 0.16s
#     Sequence length    : 36
#     Tokens             : 182
#     Token throughput   : 1.98 tokens/s
#
#   ROLLING PERFORMANCE
#     Mean batch         : 56.966s
#     Median batch       : 55.461s
#     P95 batch          : 91.762s
#     Max batch          : 135.541s
#     Slow batches       : 1
#     Current anomaly    : NO
#
#   MEMORY / STORAGE
#     RAM available      : 0.95 GiB
#     Process RSS        : 0.593719482421875
#     Peak RSS           : 4.87 GiB
#     Minimum RAM        : 0.67 GiB
#     External free      : 1636.18 GiB
#     Successful batches : 137
#     Debug batch output : ON
# ────────────────────────────────────────────────────────────────────────────────────────
# [runtime] periodic runtime telemetry

# %%
# =============================================================================
# CELL 4 – COLLECT ALL RESULTS FROM DISK (PARTIAL INCLUDED)
# =============================================================================

exp_root = Path("/Volumes/Amirali/hidden_states/experiments/baseline_v5_001")
df_results = load_experiment_results(exp_root)

if not df_results.empty:
    display_title("Extraction Progress")
    display(df_results[['model', 'dataset', 'status', 'completed_samples', 'total_samples']].head(15))
    display_info(f"Total dataset‑model pairs found: <b>{len(df_results)}</b>")
else:
    display_info("No extraction metadata found yet. Run the extraction first (Cell 3).")

# %%
# =============================================================================
# CELL 4.5 – FULL EXPERIMENT AUDIT & VALIDATION
# =============================================================================

from IPython.display import display, HTML
import pandas as pd
import numpy as np

# Path to your experiment
exp_root = Path("/Volumes/Amirali/hidden_states/experiments/baseline_v5_001")

display_title("🔍 Automated Audit & Validation")
display_info("Scanning all model‑dataset pairs and verifying data integrity...")

# Run the audit – this will automatically discover all pairs, validate checksums and sample IDs,
# and optionally fix issues. Set fix_issues=False if you only want a report.
audit_results = Extraction6.audit_experiment(
    experiment_root=exp_root,
    datasets=DATASETS,          # provides the original datasets for sample ID validation
    show_details=False,         # set True if you want per‑dataset detailed prints
    fix_issues=True,            # automatically correct checksum and sample ID mismatches
)

# Convert audit results to a DataFrame for easy viewing
df_audit = pd.DataFrame(audit_results)

# Keep only relevant columns for display
display_cols = [
    "model_name", "dataset_name", "n_samples", "completed_count", "status",
    "checksum_match", "sample_ids_match"
]
if not df_audit.empty:
    df_display = df_audit[display_cols].copy()

    # Clean up status strings and add icons
    status_icons = {
        "complete": "✅",
        "partial": "⏳",
        "missing_files": "❌",
        "missing_metadata": "⚠️",
    }
    df_display["status_icon"] = df_display["status"].map(status_icons).fillna("❓")

    # Boolean columns to checkmarks
    def bool_to_icon(val):
        if val is True:
            return "✅"
        elif val is False:
            return "❌"
        else:
            return "—"

    df_display["checksum"] = df_display["checksum_match"].apply(bool_to_icon)
    df_display["sample_ids"] = df_display["sample_ids_match"].apply(bool_to_icon)

    # Reorder columns for a clean table
    final_cols = ["model_name", "dataset_name", "n_samples", "completed_count", "status_icon", "checksum", "sample_ids"]
    df_final = df_display[final_cols].rename(columns={
        "model_name": "Model",
        "dataset_name": "Dataset",
        "n_samples": "Total Samples",
        "completed_count": "Completed",
        "status_icon": "Status",
        "checksum": "Checksum",
        "sample_ids": "Sample IDs",
    })

    # Create a styled HTML table with custom colors
    def color_status(val):
        if val == "✅":
            return "color: #4caf50;"
        elif val == "⏳":
            return "color: #ff9800;"
        elif val == "❌":
            return "color: #f44336;"
        elif val == "⚠️":
            return "color: #ffeb3b;"
        return ""

    # Display the table
    display(HTML("<h3>Audit Summary – All Model‑Dataset Pairs</h3>"))
    styled_df = df_final.style.applymap(color_status, subset=["Status"])
    display(styled_df)

    # Summary statistics
    total_pairs = len(df_audit)
    complete = (df_audit["status"] == "complete").sum()
    partial = (df_audit["status"] == "partial").sum()
    missing = (df_audit["status"].isin(["missing_files", "missing_metadata"])).sum()
    checksum_ok = df_audit["checksum_match"].sum() if "checksum_match" in df_audit else 0
    ids_ok = df_audit["sample_ids_match"].sum() if "sample_ids_match" in df_audit else 0
    actions_taken = sum(len(r.get("actions_taken", [])) for r in audit_results)

    display_info(f"""
    <b>Total pairs scanned:</b> {total_pairs} &nbsp;|&nbsp;
    <b>✅ Complete:</b> {complete} &nbsp;|&nbsp;
    <b>⏳ Partial:</b> {partial} &nbsp;|&nbsp;
    <b>❌ Missing/Error:</b> {missing} &nbsp;|&nbsp;
    <b>🔧 Checksum OK:</b> {checksum_ok} &nbsp;|&nbsp;
    <b>🔧 Sample IDs OK:</b> {ids_ok} &nbsp;|&nbsp;
    <b>🛠️ Issues fixed:</b> {actions_taken}
    """)

    # Optionally print model-level summary (which models are fully complete)
    model_summary = df_audit.groupby("model_name").apply(
        lambda g: pd.Series({
            "total_datasets": len(g),
            "complete": (g["status"] == "complete").sum(),
            "partial": (g["status"] == "partial").sum(),
            "missing": (g["status"].isin(["missing_files", "missing_metadata"])).sum(),
        })
    ).reset_index()
    model_summary.columns = ["Model", "Datasets", "Complete", "Partial", "Missing/Error"]

    display(HTML("<h3>Per‑Model Completeness</h3>"))
    display(model_summary)

else:
    display_info("No extraction data found to audit.")

# %%
# =============================================================================
# CELL 5 – VISUALISATIONS & ANALYSIS
# =============================================================================

if not df_results.empty:
    # Prepare data for plotting
    df = df_results.copy()
    df['completion_pct'] = df['completed_samples'] / df['total_samples'] * 100
    df['status_clean'] = df['status'].replace({'complete': 'Complete', 'partial': 'Partial', 'failed': 'Failed', 'already_complete': 'Already Complete'})

    sns.set_style("darkgrid")
    plt.rcParams.update({
        'figure.facecolor': '#1e1e1e',
        'axes.facecolor': '#2d2d2d',
        'axes.edgecolor': '#d4d4d4',
        'axes.labelcolor': '#d4d4d4',
        'text.color': '#d4d4d4',
        'xtick.color': '#d4d4d4',
        'ytick.color': '#d4d4d4',
        'grid.color': '#444444',
        'legend.facecolor': '#2d2d2d',
        'legend.edgecolor': '#d4d4d4',
    })

    # ---- 1. Completion status per model/dataset ----
    fig, ax = plt.subplots(figsize=(12, 8))
    pivot = df.pivot_table(index='model', columns='dataset', values='completion_pct', aggfunc='max')
    sns.heatmap(pivot, annot=True, fmt=".0f", cmap="viridis", cbar_kws={'label': 'Completion %'}, ax=ax)
    ax.set_title('Completion Percentage by Model and Dataset', color='#4fc3f7')
    plt.tight_layout()
    plt.show()

    # ---- 2. Throughput (samples/sec) by model ----
    df_complete = df[df['samples_per_second'].notna()]
    if not df_complete.empty:
        fig, ax = plt.subplots(figsize=(14, 6))
        sns.barplot(data=df_complete, x='model', y='samples_per_second', hue='dataset', palette='coolwarm', ax=ax)
        ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha='right')
        ax.set_title('Extraction Throughput (samples/sec)', color='#4fc3f7')
        plt.tight_layout()
        plt.show()

    # ---- 3. Total time per model ----
    df_time = df.groupby('model')['elapsed_seconds'].sum().reset_index().sort_values('elapsed_seconds', ascending=False)
    fig, ax = plt.subplots(figsize=(12, 6))
    sns.barplot(data=df_time, x='elapsed_seconds', y='model', palette='magma', ax=ax)
    ax.set_xlabel('Total Elapsed Time (seconds)')
    ax.set_title('Cumulative Extraction Time per Model', color='#4fc3f7')
    plt.tight_layout()
    plt.show()

    # ---- 4. Label coverage for completed datasets ----
    # We'll just display label column info
    display_title("Label Columns Used")
    display(df[['model', 'dataset', 'label_column']].drop_duplicates())
else:
    display_info("No data to visualise. Please run extraction first.")

# %%
# =============================================================================
# CELL 6 – FINAL SUMMARY & EXPORT
# =============================================================================

if not df_results.empty:
    # Save consolidated CSV
    output_csv = exp_root / "extraction_summary.csv"
    df_results.to_csv(output_csv, index=False)
    display_title("Final Report")
    display(df_results)
    display_info(f"Report exported to <code>{output_csv}</code>")
else:
    display_info("Nothing to export yet.")

# %%
discover_extractions(exp_root)

# %%
# Check which models have at least one dataset complete
model_status = df_results.groupby("model")["dataset"].nunique()
print(model_status)
